# %% [markdown]
# # Intro to Natural Language Processing (NLP)
#
# The Natural Language Processing (NLP) field is incredibly vast, and it has applications in virtually every aspect of data science. In this notebook, we will walk through a **very brief** survey of NLP, and provide some instruction on a couple handy tools along the way.
#
# NLP tools span a wide range of implementations, and it is not uncommon for NLP packages to have conflicts with other Python libraries. So, to keep everything compatible in one place, it is recommended that you create a new pip environment for NLP projects. To set up an NLP pip environment for this lab, follow the steps in the "Pip Environment" section of the [Python Environment Setup page in Canvas](https://iu.instructure.com/courses/2181786/pages/week-1-%7C-python-environment-setup?module_item_id=30340853), and **use the *environment.yml* file provided in this folder.** This should install the packages you'll need for this lab.
#
# Next, **[download a spaCy NLP model](https://spacy.io/models)** based on your preferences (in the NLP environment) so you can use the spaCy library installed in the environment.
#
# *Optionally, if you prefer to use a different environment, install the following packages separately using pip: [Scikit-Learn](https://scikit-learn.org/stable/install.html#installing-the-latest-release), [spaCy](https://spacy.io/usage), [ScatterText](https://github.com/JasonKessler/scattertext#installation), [CorEx](https://ryanjgallagher.github.io/code/corex/example), and [vaderSentiment](https://github.com/cjhutto/vaderSentiment#installation).*

# %% [markdown]
# ## Preprocessing
#
# To illustrate preprocessing text data, we'll use the [spaCy](https://spacy.io/) package.
#
# *spaCy is capable of **much** more than what we will use it for in this lab. More advanced implementations of spaCy may require knowledge outside the scope of this course.*

# %%
import pandas as pd
import spacy
from spacy import displacy
print(spacy.__version__)
# Out:
# 3.7.4

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
# %config InlineBackend.figure_formats = ['svg']

# %% [markdown]
# ### Tokenizing
#
# The very first part of dealing with text data is to collect each **term** or unitary element of text (e.g., words, punctuation, etc.) in the form of "tokens".

# %%
# depends on your choice of spaCy model
nlp = spacy.load('en_core_web_sm')

# %%
intro = '''The Natural Language Processing (NLP) field is incredibly vast,
and it has applications in virtually every aspect of data science.
In this notebook, we will walk through a **very brief** survey of NLP,
and provide some instruction on a couple handy tools along the way.
'''

doc = nlp(intro)

# %%
print([t.text for t in doc])
# Out:
# ['The', 'Natural', 'Language', 'Processing', '(', 'NLP', ')', 'field', 'is', 'incredibly', 'vast', ',', '\n', 'and', 'it', 'has', 'applications', 'in', 'virtually', 'every', 'aspect', 'of', 'data', 'science', '.', '\n', 'In', 'this', 'notebook', ',', 'we', 'will', 'walk', 'through', 'a', '*', '*', 'very', 'brief', '*', '*', 'survey', 'of', 'NLP', ',', '\n', 'and', 'provide', 'some', 'instruction', 'on', 'a', 'couple', 'handy', 'tools', 'along', 'the', 'way', '.', '\n']

# %%
for i, sentence in enumerate(doc.sents):
    print(f"sentence {i+1}\n\n", sentence)
# Out:
# sentence 1
#
#  The Natural Language Processing (NLP) field is incredibly vast,
# and it has applications in virtually every aspect of data science.
#
# sentence 2
#
#  In this notebook, we will walk through a **very brief** survey of NLP,
# and provide some instruction on a couple handy tools along the way.

# %%
df_intro = []

for token in doc:
    df_intro.append([
        token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
        token.shape_, token.is_alpha, token.is_stop
    ])

# %%
df_intro = pd.DataFrame(columns=["text", "lemma_", "pos_", "tag_", "dep_", "shape_", "is_alpha", "is_stop"],
                        data=df_intro)

# %%
df_intro.sample(5)
# Out:
#           text      lemma_   pos_ tag_    dep_ shape_  is_alpha  is_stop
# 9   incredibly  incredibly    ADV   RB  advmod   xxxx      True    False
# 3   Processing  Processing  PROPN  NNP    nmod  Xxxxx      True    False
# 58           .           .  PUNCT    .   punct      .     False    False
# 52      couple      couple   NOUN   NN  nummod   xxxx      True    False
# 12          \n          \n  SPACE  _SP     dep     \n     False    False

# %% [markdown]
# What is a **stop word**?

# %%
df_intro[df_intro['is_stop']].sample(10)
# Out:
#      text lemma_  pos_ tag_    dep_ shape_  is_alpha  is_stop
# 37   very   very   ADV   RB  advmod   xxxx      True     True
# 42     of     of   ADP   IN    prep     xx      True     True
# 30     we     we  PRON  PRP   nsubj     xx      True     True
# 31   will   will   AUX   MD     aux   xxxx      True     True
# 17     in     in   ADP   IN    prep     xx      True     True
# 48   some   some   DET   DT     det   xxxx      True     True
# 26     In     in   ADP   IN    prep     Xx      True     True
# 14     it     it  PRON  PRP   nsubj     xx      True     True
# 21     of     of   ADP   IN    prep     xx      True     True
# 55  along  along   ADP   IN    prep   xxxx      True     True

# %% [markdown]
# spaCy defines **lemmas** to be *"the base forms of words. For example, the lemma of `was` is `be`, and the lemma of `rats` is `rat`."*

# %%
t = nlp('running')[0]
t.lemma_
# Out:
# 'run'

# %% [markdown]
# **Sentence Dependencies**

# %% [markdown]
# We can visualize some of these attributes (like the sentence dependencies) using [displacy](https://spacy.io/usage/visualizers).

# %%
doc = nlp('We can visualize these using displacy.')

# %%
displacy.render(doc, style='dep', options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b9d9207e77bd4e6bb1f9169a581ac4f8-0" class="displacy" width="770" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">We</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">visualize</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">these</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">using</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">displacy.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b9d9207e77bd4e6bb1f9169a581ac4f8-0-0" stroke-width="2px" d="M70,182.0 C70,62.0 285.0,62.0 285.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b9d9207e77bd4e6bb1f9169a581ac4f8-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b9d9207e77bd4e6bb1f9169a581ac4f8-0-1" stroke-width="2px" d="M190,182.0 C190,122.0 280.0,122.0 280.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b9d9207e77bd4e6bb1f9169a581ac4f8-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,184.0 L182,172.0 198,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b9d9207e77bd4e6bb1f9169a581ac4f8-0-2" stroke-width="2px" d="M430,182.0 C430,62.0 645.0,62.0 645.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b9d9207e77bd4e6bb1f9169a581ac4f8-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,184.0 L422,172.0 438,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b9d9207e77bd4e6bb1f9169a581ac4f8-0-3" stroke-width="2px" d="M550,182.0 C550,122.0 640.0,122.0 640.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b9d9207e77bd4e6bb1f9169a581ac4f8-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,184.0 L542,172.0 558,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b9d9207e77bd4e6bb1f9169a581ac4f8-0-4" stroke-width="2px" d="M310,182.0 C310,2.0 650.0,2.0 650.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b9d9207e77bd4e6bb1f9169a581ac4f8-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M650.0,184.0 L658.0,172.0 642.0,172.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# Note: this isn't always going to be *exactly* accurate, but it's very good and still useful.

# %% [markdown]
# ### Named Entity Recognition
#
# Some words are **Named Entities**: locations like "Alaska", dates like "January 1st", companies like "Google", etc. spaCy can tag these using [Named Entity Recognition](https://spacy.io/usage/linguistic-features#named-entities).

# %%
doc = nlp('... locations like "Alaska", dates like "January 1st", companies like "Google", etc.')

# %%
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">... locations like &quot;
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alaska
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# &quot;, dates like &quot;
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     January 1st
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# &quot;, companies like &quot;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# &quot;, etc.</div></span>

# %% [markdown]
# ### Multiple Documents
#
# *NLP Terms: A **document** is a collection of **tokens**, and a **corpus** is a collection of documents.*
#
# When spaCy processes text, it runs it through a [pipeline](https://spacy.io/usage/processing-pipelines) of different models to store token attributes for each token. This is how we get the functionality above. Though, when we are tokenizing multiple documents, we might not need all of these [built-in components](https://spacy.io/usage/processing-pipelines#built-in). For example, we might just need enough to filter our text based on the analysis done.
#
# For example, suppose we've determined that we want to the remove the following tokens from a dataset of [coffee reviews](https://www.kaggle.com/datasets/schmoyote/coffee-reviews-dataset/) (descriptions):
#
# - stop words (except the lemma "not", to maintain the idea of object negation)
# - punctuation
# - numbers
#
# In this case, we don't need NER, Dependency Labels, or Document Labels. Removing these processes from the spaCy pipeline will save us some time.

# %%
df_coffee = pd.read_csv('./data/coffee_analysis.csv')

# %%
df_coffee.drop_duplicates(subset='desc_1', inplace=True)

# %%
df_coffee.shape
# Out:
# (2092, 12)

# %%
print(df_coffee['desc_1'].sample().iloc[0])
# Out:
# Gently fruit-toned, lyrically sweet. Nectarine, cherry blossom, almond butter, oregano, honey in aroma and cup. Richly sweet with high-toned acidity; full, syrupy mouthfeel. Integrated finish that retains all the notes from the aroma and cup.

# %%
# nlp.pipe returns a generator
docs = nlp.pipe(df_coffee['desc_1'], disable=['ner', 'parser', 'textcat'])

# save the spaCy objects into the DataFrame
df_coffee['spacy_doc'] = list(docs)

# %%
def tokenizer(doc, join_tokens=False):
    '''
    Tokenize a single spaCy `doc`.

    join_tokens : bool
        Whether we want to return a list of strings or
        a list of lists. If True, join with space (" ").
    '''

    # collect lemmas that meet the following criteria:
    tokens = [w.lemma_.lower() for w in doc if
              (not w.is_stop
               and not w.is_punct
               and not w.like_num) \
              or (w.lemma_ == 'not')]

    if join_tokens:
        return ' '.join(tokens)
    else:
        return tokens

# %%
df_coffee['docs_clean'] = df_coffee['spacy_doc'].apply(tokenizer)

# %%
df_coffee[['desc_1', 'spacy_doc', 'docs_clean']].head()
# Out:
#                                               desc_1  \
# 0  Evaluated as espresso. Sweet-toned, deeply ric...
# 1  Evaluated as espresso. Sweetly tart, floral-to...
# 2  Crisply sweet, cocoa-toned. Lemon blossom, roa...
# 3  Delicate, sweetly spice-toned. Pink peppercorn...
# 4  Deeply sweet, subtly pungent. Honey, pear, tan...
#
#                                            spacy_doc  \
# 0  (Evaluated, as, espresso, ., Sweet, -, toned, ...
# 1  (Evaluated, as, espresso, ., Sweetly, tart, ,,...
# 2  (Crisply, sweet, ,, cocoa, -, toned, ., Lemon,...
# 3  (Delicate, ,, sweetly, spice, -, toned, ., Pin...
# 4  (Deeply, sweet, ,, subtly, pungent, ., Honey, ...
#
#                                           docs_clean
# 0  [evaluate, espresso, sweet, tone, deeply, rich...
# 1  [evaluate, espresso, sweetly, tart, floral, to...
# 2  [crisply, sweet, cocoa, tone, lemon, blossom, ...
# 3  [delicate, sweetly, spice, tone, pink, pepperc...
# 4  [deeply, sweet, subtly, pungent, honey, pear, ...

# %%
print(df_coffee['desc_1'].iloc[5])
# Out:
# Delicate, richly and sweetly tart. Dried hibiscus, fine musk, almond, sandalwood, raspberry in aroma and cup. Fruit-toned, deeply sweet structure with gently-expressed acidity; buoyant, satiny-smooth mouthfeel. The crisp, flavor-saturated finish is characterized by sweet-tart fruit and floral tones (raspberry, hibiscus).

# %%
print(df_coffee['docs_clean'].iloc[5])
# Out:
# ['delicate', 'richly', 'sweetly', 'tart', 'dry', 'hibiscus', 'fine', 'musk', 'almond', 'sandalwood', 'raspberry', 'aroma', 'cup', 'fruit', 'tone', 'deeply', 'sweet', 'structure', 'gently', 'express', 'acidity', 'buoyant', 'satiny', 'smooth', 'mouthfeel', 'crisp', 'flavor', 'saturate', 'finish', 'characterize', 'sweet', 'tart', 'fruit', 'floral', 'tone', 'raspberry', 'hibiscus']

# %% [markdown]
# ## Vectorization
#
# Once we have our tokens selected and "cleaned", we need to convert the textual data into numerical data. **In other words, we need to convert each token (or document) into a *vector* representation.** There are many ways to represent textual information in the form of numerical data, but in this class we will cover Count Vectorization and Term-Frequency Inverse Document Frequency Vectorization; we'll call these **vectorizers**.

# %% [markdown]
# ### Brief Intro to Scikit-Learn
#
# **[Scikit-Learn](https://scikit-learn.org/stable/index.html) is the industry standard data science toolkit**, and it's modules are used in almost every aspect of data science. Here, we are going to use its [feature extraction module](https://scikit-learn.org/stable/modules/feature_extraction.html), which is built for extracting numerical features from data such as text or images. We will be using it for vectorization of text data, and in these cases, the scikit-learn process is:
#
# 1. Preprocess some data (e.g., from text to tokens)
# 2. Define a model (e.g., a vectorizer)
# 3. "Fit" that model to the data using `.fit`
# 4. Transform the data based on the model's parameters using `.transform`
#     - We can also combine these last two steps with `.fit_transform`

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %% [markdown]
# ### CountVectorizer
#
# CountVectorizer converts each document into a "Bag of Words". In other words, the document is encoded based on the words it contains, **regardless of the order**. And, each term can be represented based on the documents it is contained in.

# %%
corpus_raw = ['This coffee is really really tasty.',
              'Tea smells and tastes better than coffee.',
              "Best smelling coffee I have ever smelled!"]

# %%
cv = CountVectorizer(ngram_range=(1, 1),  # capture "pairs", or "n-tuples" of adjacent words
                     max_df=1.0,          # exclude terms in ≥ `max_df` (or %) of docs
                     min_df=1,            # exclude terms in ≤ `min_df` (or %) of docs
                     max_features=None,   # maximum number of terms/ngrams to include
                     binary=False)        # only log 1s and 0s for term presence

X = cv.fit_transform(corpus_raw)

df = pd.DataFrame(X.toarray(),
                  index=corpus_raw,
                  columns=cv.get_feature_names_out())

# %%
plt.figure(figsize=(8, 1))
g = sns.heatmap(df, cmap='Blues', annot=True, cbar=False, linewidths=1)

# %% [markdown]
# This is called a **document-term matrix**.
#
# - We could use `max_df` to remove the term "coffee" since it occurs in every document. This is one example of extracting *informative* features from text; i.e., the term "coffee" doesn't provide new information for each document.
# - Also, we can already see that some of these words give us more information than others. For example, "smelling" and "smells" mean roughly the same thing, and "had"/"have" aren't really necessary for understanding reviews.
#
# This is why we use the filtering in spaCy.

# %%
docs = nlp.pipe(corpus_raw)
corpus_clean = [tokenizer(d, True) for d in docs]
corpus_clean
# Out:
# ['coffee tasty', 'tea smell taste well coffee', 'good smell coffee smell']

# %%
cv = CountVectorizer(ngram_range=(1, 1),
                     max_df=0.9,
                     min_df=1,
                     max_features=None,
                     binary=False)

X = cv.fit_transform(corpus_clean)

df = pd.DataFrame(X.toarray(),
                  index=corpus_raw,
                  columns=cv.get_feature_names_out())

# %%
plt.figure(figsize=(6, 1))
g = sns.heatmap(df, cmap='Blues', annot=True, cbar=False, linewidths=1)

# %%
cv = CountVectorizer(ngram_range=(2, 2),  # use (1, 2) for unigrams *and* bigrams
                     max_df=0.9,
                     min_df=1,
                     max_features=None,
                     binary=False)

X = cv.fit_transform(corpus_clean)

df = pd.DataFrame(X.toarray(),
                  index=corpus_clean,
                  columns=cv.get_feature_names_out())

# %%
plt.figure(figsize=(10, 1))
g = sns.heatmap(df, cmap='Blues', annot=True, cbar=False, linewidths=1)

# %% [markdown]
# Now these vectors are a bit more meaningful. Notice, in a way, bigrams are a contrived way to capture context in textual data.

# %% [markdown]
# ### TFIDF Vectorizer
#
# Downsides of Count Vectorizer:
#
# - Counts can be too simplistic
# - High counts can dominate, especially for high frequency words or long documents
# - Each word is treated equally, when some terms might be more "important" than others
#
# We define TFIDF as:
#
# $$
# \text{TF-IDF} = \text{term frequency} * \text{inverse document frequency}
# $$
#
# where:
#
# $$
# \begin{align*}
# \text{term frequency} &= \frac{\text{term count in document}}{\text{total terms in document}} \\[8pt]
# \text{inverse document frequency} &= \log\bigg(\frac{\text{total number of documents} + 1}{\text{number of documents with term} + 1}\bigg)
# \end{align*}
# $$

# %% [markdown]
# This measure is calculated for every term-document combination:
#
# - The **term frequency** measures the "density" of a word in a document
# - The **inverse document frequency** (without the $\log$) measures the size of the corpus *in terms of* the number of documents containing the term. E.g., if IDF=5 then the corpus is 5 times the size of the "sub-corpus" of documents containing the term. The $\log$ dampens the effect of the inverse document frequency as the denominator gets very small or the numerator gets very large.
#
# So, we can think of TF as the "main" measure, and IDF as the "scaling" factor:
#
# - Very common words across all documents will get a lower score.
# - Rare words considering all documents get a higher score.

# %%
cv = TfidfVectorizer(max_df=1.0,
                     min_df=1,
                     max_features=None)

X = cv.fit_transform(corpus_clean)

df = pd.DataFrame(X.toarray(),
                  index=corpus_clean,
                  columns=cv.get_feature_names_out())

# %%
sns.heatmap(df, square=True, cmap='Blues', annot=True, cbar=False);

# %% [markdown]
# ## Topic Modeling
#
# ### Matrix Decomposition
#
# The document term matrix $X$ is a matrix just like any other in Linear Algebra. Just so, it defines a row space (the documents represented as linear combinations of terms), and column space (terms represented as a linear combination of documents). With this, there are a few matrix decomposition methods we can use to extract further information about these documents and terms.

# %%
from sklearn.decomposition import TruncatedSVD, NMF, PCA

# %% [markdown]
# ### Singular Value Decomposition
#
# Singular Value Decomposition is a guaranteed decomposition for any rectangular matrix. It creates the following equality:
#
# $$
# X = U\Sigma V^\top
# $$
#
# **Breifly**:
# - Each row of $U$ represents the corresponding document in terms of "topics directions" along the columns.
# - The rows of $V$ (columns of $V^\top$) represent similarly represented version of the terms.
# - The $\Sigma$ matrix contains the "variance explained" by each of these topics, sorted in descending order.
#
# As far as naming goes:
#
# - The analysis of these resulting matrices is called **Principal Components Analysis (PCA)**.
# - When used with text data, this analysis is called **Latent Semantic Analysis (LSA)**.

# %%
# we need a list/array of strings to vectorize
corpus = df_coffee['spacy_doc'].apply(tokenizer, args={'join_tokens':True})

# %%
corpus.shape
# Out:
# (2092,)

# %%
cv = TfidfVectorizer(max_df=0.9,
                     min_df=0.1,
                     max_features=None)

X = cv.fit_transform(corpus)
# df = pd.DataFrame(X, index=corpus, columns=cv.get_feature_names_out())

# %%
X.shape
# Out:
# (2092, 65)

# %% [markdown]
# Note, we use `TruncatedSVD` here because it's a more efficient implementation of SVD. PCA centers the data before running the algorithm, which is more "appropriate" but takes more time. This does cause a few inconsistencies in the "sorted" $\Sigma$.

# %%
lsa = TruncatedSVD(n_components=5)  # results only change for larger (unseen) values

doc_topic = lsa.fit_transform(X)
lsa.explained_variance_ratio_
# Out:
# array([0.00488089, 0.08197356, 0.04778192, 0.04678051, 0.03502022])

# %%
doc_topic = pd.DataFrame(doc_topic.round(3),
                         index=df_coffee['desc_1'])
# doc_topic.head()

# %%
topic = 1
n_docs = 5

print(f"Top Documents for topic {topic}:\n")

for doc in doc_topic[topic].abs().sort_values(ascending=False).iloc[:n_docs].index:
    print(doc, '\n')
# Out:
# Top Documents for topic 1:
#
# Sweetly floral and delicately cocoa-toned. Honeysuckle, cocoa nib, Concord grape, agave, lemon-thyme in aroma and cup. High-toned structure with juicy, confident acidity; buoyant, lively, viscous mouthfeel. Honeysuckle and cocoa nib characterize the sweet finish.
#
# Evaluated as espresso. Roast-rounded, chocolaty. Dark chocolate, gardenia, gently scorched cedar, molasses, prune in aroma and small cup. Viscous, creamy mouthfeel; chocolaty, slightly smoky finish. In three parts milk, floral and chocolate notes preside.
#
# Evaluated as espresso. Fruit-forward, chocolaty. Dark chocolate, black cherry, lily, molasses, cedar in aroma and small cup. Very syrupy mouthfeel; crisp, chocolaty finish. In three parts milk, dark chocolate notes take center stage, supported by notes of black cherry and lily.
#
# Evaluated as espresso. Bittersweet, richly pungent, chocolaty and floral. Dark chocolate, plum, cedar, magnolia in aroma and small cup. Plump, satiny mouthfeel; bittersweet and chocolaty in the finish. Chocolate and flowers dominate in three parts milk.
#
# Delicately sweet-tart, floral-toned. Narcissus, apricot, cocoa nib, lemon verbena, frankincense in aroma and cup. Sweet-tart structure with delicately juicy acidity; very full, syrupy mouthfeel. Cocoa nib and narcissus focus the long, lingering finish.

# %%
topic_term = pd.DataFrame(lsa.components_.round(3),
                          columns = cv.get_feature_names_out())

topic_term
# Out:
#    acidity  almond   bake  balanced  bright  brisk  butter  cedar  center  \
# 0    0.192   0.124  0.090     0.103   0.117  0.072   0.068  0.167   0.082
# 1    0.072  -0.025 -0.142     0.065   0.120 -0.019  -0.019 -0.107  -0.003
# 2    0.039   0.064  0.298    -0.045  -0.126  0.195   0.061  0.145  -0.007
# 3   -0.121   0.008 -0.114    -0.008   0.010 -0.088   0.030  0.064  -0.013
# 4   -0.086  -0.160 -0.128     0.011  -0.165 -0.028  -0.084 -0.082  -0.059
#
#    chocolate  ...  sweet  sweetly  syrup  syrupy   tart   tone  undertone  \
# 0      0.256  ...  0.280    0.146  0.079   0.144  0.195  0.249      0.077
# 1     -0.461  ...  0.034    0.029  0.041   0.038  0.113  0.032     -0.016
# 2     -0.070  ...  0.098   -0.059  0.057  -0.146 -0.108  0.111      0.058
# 3     -0.029  ... -0.173   -0.038 -0.045  -0.042  0.034  0.096      0.006
# 4     -0.073  ...  0.080   -0.132 -0.062   0.047 -0.363 -0.072      0.029
#
#    velvety  vibrant   zest
# 0    0.070    0.066  0.148
# 1   -0.046    0.070  0.040
# 2    0.125   -0.089  0.013
# 3   -0.014   -0.017  0.011
# 4    0.023   -0.053 -0.062
#
# [5 rows x 65 columns]

# %%
# the third "topic"
topic = 2
n_terms = 10

topic_term.T[topic].abs().sort_values(ascending=False).iloc[:n_terms]
# Out:
# bake          0.298
# sandalwood    0.265
# dark          0.251
# nut           0.235
# flavor        0.217
# savory        0.216
# juicy         0.205
# cut           0.204
# hazelnut      0.200
# brisk         0.195
# Name: 2, dtype: float64

# %% [markdown]
# ### Non-Negative Matrix Factorization
#
# [NMF](https://en.wikipedia.org/wiki/Non-negative_matrix_factorization) is very similar to SVD. Here, we have the following decomposition.
#
# $$
# X = WH
# $$
#
# In this case though, all values in $W$ and $H$ are positive, and we can *approximate* this decomposition because all values in $X$ are positive.

# %%
nmf = NMF(4)  # here, the number will change the results
doc_topic = nmf.fit_transform(X)

# %%
doc_topic = pd.DataFrame(doc_topic.round(3),
                         index=df_coffee['desc_1'])
# doc_topic.head()

# %%
topic = 1
n_docs = 5

print(f"Top Documents for topic {topic}:\n")

for doc in doc_topic[topic].abs().sort_values(ascending=False).iloc[:n_docs].index:
    print(doc, '\n')
# Out:
# Top Documents for topic 1:
#
# Evaluated as espresso. Fruit-forward, chocolaty. Dark chocolate, black cherry, lily, molasses, cedar in aroma and small cup. Very syrupy mouthfeel; crisp, chocolaty finish. In three parts milk, dark chocolate notes take center stage, supported by notes of black cherry and lily.
#
# Evaluated as espresso. Bittersweet, richly pungent, chocolaty and floral. Dark chocolate, plum, cedar, magnolia in aroma and small cup. Plump, satiny mouthfeel; bittersweet and chocolaty in the finish. Chocolate and flowers dominate in three parts milk.
#
# Evaluated as espresso. Deeply chocolaty, balanced, roast-rounded. Dark chocolate, nectarine, molasses, gently scorched cedar, rhododendron in aroma and small cup. Full, satiny mouthfeel; crisp, chocolaty finish. In three parts milk the dark chocolate notes are amplified, as are the florals
#
# Evaluated as espresso. Roast-rounded, chocolaty. Dark chocolate, gardenia, gently scorched cedar, molasses, prune in aroma and small cup. Viscous, creamy mouthfeel; chocolaty, slightly smoky finish. In three parts milk, floral and chocolate notes preside.
#
# Evaluated as espresso. Richly chocolaty, fruit-toned. Dark chocolate, raspberry jam, cedar, caramel, lemon verbena in aroma and small cup. Crisp, syrupy-smooth mouthfeel; chocolaty, sweetly herbaceous finish. In three parts milk, raspberry notes recede and caramel and chocolate come forward.

# %%
topic_term = pd.DataFrame(nmf.components_.round(3),
                          columns = cv.get_feature_names_out())

topic_term
# Out:
#    acidity  almond   bake  balanced  bright  brisk  butter  cedar  center  \
# 0    0.934   0.391  0.000     0.612   0.863  0.000   0.083  0.022   0.351
# 1    0.000   0.173  0.000     0.047   0.000  0.000   0.133  0.603   0.114
# 2    0.547   0.485  0.961     0.104   0.000  0.611   0.301  0.660   0.210
# 3    0.492   0.163  0.000     0.363   0.487  0.017   0.112  0.284   0.167
#
#    chocolate  ...  sweet  sweetly  syrup  syrupy   tart   tone  undertone  \
# 0      0.805  ...  1.422    0.898  0.234   1.221  0.997  0.602      0.091
# 1      1.579  ...  0.029    0.135  0.000   0.173  0.178  0.398      0.179
# 2      0.709  ...  0.897    0.238  0.294   0.032  0.199  0.702      0.276
# 3      0.000  ...  0.503    0.333  0.230   0.308  0.705  0.737      0.192
#
#    velvety  vibrant   zest
# 0    0.000    0.557  0.650
# 1    0.118    0.000  0.136
# 2    0.438    0.000  0.353
# 3    0.048    0.260  0.377
#
# [4 rows x 65 columns]

# %%
topic = 0
n_terms = 10

topic_term.T[topic].sort_values(ascending=False).iloc[:n_terms]
# Out:
# savory        2.346
# sweet         1.422
# long          1.284
# flavor        1.231
# syrupy        1.221
# sandalwood    1.121
# juicy         1.121
# structure     1.107
# resonant      1.048
# richly        1.023
# Name: 0, dtype: float64

# %%
topic = 1
n_terms = 10

topic_term.T[topic].sort_values(ascending=False).iloc[:n_terms]
# Out:
# chocolate    1.579
# dark         1.304
# milk         1.131
# espresso     1.126
# evaluate     1.099
# small        1.097
# chocolaty    1.014
# cedar        0.603
# fruit        0.520
# floral       0.493
# Name: 1, dtype: float64

# %% [markdown]
# As you can tell, this often produces more agreeable results than LSA.

# %% [markdown]
# ### Latent Dirichlet Allocation (LDA)
#
# [LDA](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.LatentDirichletAllocation.html) is a "generative" model that builds topics with the assumption that documents are generated based on a probability distribution of topics, and that topics are just a probability distribution of terms.

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
# these parameters usually require a good bit of tuning ...
lda = LatentDirichletAllocation(n_components=5,
                                max_iter=50)

X_topics = lda.fit_transform(X)

# %%
df_lda = pd.DataFrame(data = X_topics,
                      index = corpus)

# %%
topic = 0
n_docs = 3

for d in df_lda[topic].sort_values(ascending=False).iloc[:n_docs].index:
    print(d, '\n')
# Out:
# rich toned deeply sweetly earthy chocolate fudge white sage blackberry perique pipe tobacco plumeria like flower aroma cup balanced sweet savory structure vibrant juicy acidity delicate satiny mouthfeel resonant flavor saturate finish display note blackberry tobacco short plumeria sage long deep chocolate
#
# high tone sweetly tart deeply savory jasmine dark chocolate lemon verbena pink grapefruit zest candycap mushroom aroma cup balanced sweet tart savory structure lyrical syrupy smooth mouthfeel flavor saturate finish lead citrus note lemon verbena grapefruit short round deep chocolate sweet mushroom long
#
# crisply sweet spice tone dry papaya caramel tangerine zest pink peppercorn vanilla aroma cup high tone sweetly tart structure juicy bright acidity lean satiny smooth mouthfeel resonant richly dry finish laden sweet note caramel papaya short turn savory lean long hint pink peppercorn wrap vanilla

# %%
topic = 1
n_docs = 3

for d in df_lda[topic].sort_values(ascending=False).iloc[:n_docs].index:
    print(d, '\n')
# Out:
# vibrant richly sweet clear tone roasted cacao nib ginger blossom dry fig sandalwood sugar cane aroma cup lushly sweet tart structure juicy acidity crisp velvety mouthfeel deep resonant finish flavor laden fulfil promise cup spicy floral note short cocoa tone fruit long
#
# balanced richly sweet spice tone apricot cocoa nib lilac coriander amber aroma cup deep sweet savory structure bright acidity syrupy smooth mouthfeel finish crisp juicy lead note apricot coriander short rich cocoa tone floral long
#
# high tone deeply sweet black currant honey sandalwood narcissus like flower roasted cacao nib aroma cup sweet tart structure juicy bright acidity syrupy smooth mouthfeel resonant finish consolidate note black currant honey short rich cocoa tone sandalwood long

# %%
df_lda_terms = pd.DataFrame(data = lda.components_,
                            columns = cv.get_feature_names_out())

# %%
topic = 0
n_terms = 10

df_lda_terms.T[topic].sort_values(ascending=False).iloc[:n_terms]
# Out:
# chocolate    122.530006
# dark         100.575195
# savory        98.339365
# sweet         80.202245
# structure     62.881553
# acidity       54.484640
# tone          53.380504
# richly        52.551047
# tart          51.718195
# syrupy        50.623822
# Name: 0, dtype: float64

# %%
topic = 1
n_terms = 10

df_lda_terms.T[topic].sort_values(ascending=False).iloc[:n_terms]
# Out:
# cocoa        164.885024
# nib          134.858359
# tart          93.768132
# tone          88.123464
# sweet         85.869964
# juicy         79.658996
# bright        75.987789
# acidity       72.450516
# structure     65.951490
# floral        59.296914
# Name: 1, dtype: float64

# %% [markdown]
# ### Anchored Correlation Explanation (CorEx)
#
# [CorEx](https://github.com/gregversteeg/corex_topic) is a discriminative model, which starts from $X$ (documents/words) to determine $Y$ (topics). CorEx looks for groups of words that are in the same topic, a.k.a. have high Total Correlation (TC), or convey the same information.
#
# - If words are **tightly related** (always appear together in the same topic/document), TC will be high. This is a good topic.
# - If the words are all **independent** (never appear together in the same document or topic), TC = 0. This is a bad topic.
# - CorEx creates a partition across terms. I.e., **terms can only occur in a single topic**.
#
# CorEx roughly follows this algorithm:
# 1. Look for a group of words that are both as broad (in many documents) and overlapping as possible (both together will lead to high TC), and call this a topic.
# 2. Repeat the process for another set of words (not overlapping with your previous group) with as high a TC as possible, and call this the next topic.
#
# As we create more topics, each subsequent topic will have lower TC.

# %%
from corextopic import corextopic as ct

# %%
# CorEx requires count data
cv = CountVectorizer(max_df=0.9,
                     min_df=0.1,
                     max_features=None)

X = cv.fit_transform(corpus)

# %%
topic_model = ct.Corex(n_hidden=5,                        # number of topics
                       words=cv.get_feature_names_out(),  # list of terms in corpus
                       seed=1)

doc_topic = topic_model.fit_transform(X, words=cv.get_feature_names_out(), docs=corpus)

# %%
# Print all topics from the CorEx topic model
topics = topic_model.get_topics()

for n, topic in enumerate(topics):
    topic_words,_,_ = zip(*topic)
    print(f"{n}: " + ','.join(topic_words))
# Out:
# 0: espresso,evaluate,small,milk,structure,acidity,consolidate,floral,syrup,crisp
# 1: chocolate,dark,nib,cocoa,chocolaty,bake,delicate,lemon,deep,zest
# 2: juicy,cut,gentle,bright,fresh,sandalwood,brisk,tart,high,nut
# 3: short,long,lead,undertone,rich,center,almond
# 4: sweet,sweetly,savory,deeply,fruit,smooth

# %% [markdown]
# Take a look at how you can use [anchor words](https://github.com/gregversteeg/corex_topic/tree/master#using-anchor-words) to guide the topic creation.

# %% [markdown]
# ## ScatterText
#
# Scattertext is great for
# - Visually inspecting text
# - Comparing/Contrasting corpora
# - And more...
#
# Check out Jason Kessler's GitHub project for more information: [here](https://github.com/JasonKessler/scattertext).

# %%
import scattertext as st

# %%
convention_df = st.SampleCorpora.ConventionData2012.get_data()

# %%
convention_df.head()
# Out:
#       party                                               text         speaker
# 0  democrat  Thank you. Thank you. Thank you. Thank you so ...    BARACK OBAMA
# 1  democrat  Thank you so much. Tonight, I am so thrilled a...  MICHELLE OBAMA
# 2  democrat  Thank you. It is a singular honor to be here t...  RICHARD DURBIN
# 3  democrat  Hey, Delaware. \nAnd my favorite Democrat, Jil...    JOSEPH BIDEN
# 4  democrat  Hello. \nThank you, Angie. I'm so proud of how...      JILL BIDEN

# %%
corpus = st.CorpusFromPandas(convention_df,
                             category_col='party',
                             text_col='text',
                             nlp=st.whitespace_nlp_with_sentences
                            ).build()

# %%
html = st.produce_scattertext_explorer(
        corpus,
        category='democrat',
        category_name='Democratic',
        not_category_name='Republican',
        minimum_term_frequency=10,
        pmi_threshold_coefficient=5,
        width_in_pixels=1000,
        metadata=convention_df['speaker'],
        )

# %%
with open('demo.html', 'wb') as f:
    f.write(html.encode('utf-8'))

# %% [markdown]
# ## Sentiment Analysis with VADER
#
# According to the documentation:
#
#     VADER (Valence Aware Dictionary and sEntiment Reasoner) is a lexicon and rule-based sentiment analysis tool that is specifically attuned to sentiments expressed in social media. [...]
#
#     Sentiment ratings from 10 independent human raters (all pre-screened, trained, and quality checked for optimal inter-rater reliability). Over 9,000 token features were rated on a scale from "[–4] Extremely Negative" to "[4] Extremely Positive", with allowance for "[0] Neutral (or Neither, N/A)".

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
sentences = ["VADER is smart, handsome, and funny.",  # positive sentence example
             "VADER is smart, handsome, and funny!",  # punctuation emphasis handled correctly (sentiment intensity adjusted)
             "VADER is very smart, handsome, and funny.", # booster words handled correctly (sentiment intensity adjusted)
             "VADER is VERY SMART, handsome, and FUNNY.",  # emphasis for ALLCAPS handled
             "VADER is VERY SMART, handsome, and FUNNY!!!", # combination of signals - VADER appropriately adjusts intensity
             "VADER is VERY SMART, uber handsome, and FRIGGIN FUNNY!!!", # booster words & punctuation make this close to ceiling for score
             "VADER is not smart, handsome, nor funny.",  # negation sentence example
             "The book was good.",  # positive sentence
             "At least it isn't a horrible book.",  # negated negative sentence with contraction
             "The book was only kind of good.", # qualified positive sentence is handled correctly (intensity adjusted)
             "The plot was good, but the characters are uncompelling and the dialog is not great.", # mixed negation sentence
             "Today SUX!",  # negative slang with capitalization emphasis
             "Today only kinda sux! But I'll get by, lol", # mixed sentiment example with slang and constrastive conjunction "but"
             "Make sure you :) or :D today!",  # emoticons handled
             # "Catch utf-8 emoji such as such as 💘 and 💋 and 😁",  # emojis handled, ignored for seaborn plot below
             "Not bad at all"  # Capitalized negation
             ]

# %%
df_sentiment = []

analyzer = SentimentIntensityAnalyzer()

for sentence in sentences:
    vs = analyzer.polarity_scores(sentence)
    df_sentiment.append(vs)

# %%
df_sentiment = pd.DataFrame(df_sentiment,
                            index = sentences)

# %%
sns.heatmap(df_sentiment, cmap='Blues', annot=True, cbar=False, linewidths=1);

# %% [markdown]
# # EXERCISES

# %% [markdown]
# ## Exercise 1
#
# Using a book from [Project Gutenberg](https://www.gutenberg.org/), get the text data directly from its URL using the `requests` package. Break the book into 50 or more sensible "chunks" like chapters or paragraphs, organizing them into a list.
#
# Load this data into a spaCy pipeline and analyze either Named Entities or Parts of Speech in each chunk.
#
# Provide your analysis: What types of entities or parts of speech are common, and what are uncommon? What insights can you draw from these patterns?
#
# *Note*: Do not download any file, make use of URL in your code.

# %%
import requests
import spacy
nlp = spacy.load("en_core_web_sm")

# Get the text data from the URL
url = "https://www.gutenberg.org/cache/epub/73186/pg73186.txt"
response = requests.get(url)
text = response.text


chunks = text.split("\n\n")  

# Analyze each chunk using spaCy
for i, chunk in enumerate(chunks):
    doc = nlp(chunk)
    print(f"Chunk {i + 1}:")
    for token in doc:
        print(token.text, token.pos_, token.tag_, token.dep_)
    print("\n")
# Out:
# Chunk 1:
# ﻿The NOUN NN compound
# Project PROPN NNP compound
# Gutenberg PROPN NNP compound
# eBook PROPN NNP nsubj
# of ADP IN prep
# Hephæstus PROPN NNP pobj
# ; PUNCT : punct
# or CCONJ CC cc
# , PUNCT , punct
# The DET DT det
# Soul PROPN NNP appos
# of ADP IN prep
# the DET DT det
# Machine NOUN NN pobj
#
#
#  SPACE _SP dep
# This DET DT det
# ebook NOUN NN nsubj
# is AUX VBZ ROOT
# for ADP IN prep
# the DET DT det
# use NOUN NN pobj
# of ADP IN prep
# anyone PRON NN pobj
# anywhere ADV RB advmod
# in ADP IN prep
# the DET DT det
# United PROPN NNP compound
# States PROPN NNP pobj
# and CCONJ CC cc
#
#  SPACE _SP dep
# most ADJ JJS amod
# other ADJ JJ amod
# parts NOUN NNS conj
# of ADP IN prep
# the DET DT det
# world NOUN NN pobj
# at ADP IN prep
# no DET DT det
# cost NOUN NN pobj
# and CCONJ CC cc
# with ADP IN conj
# almost ADV RB advmod
# no PRON DT nummod
# restrictions NOUN NNS pobj
#
#  SPACE _SP dep
# whatsoever ADV RB advmod
# . PUNCT . punct
# You PRON PRP nsubj
# may AUX MD aux
# copy VERB VB ROOT
# it PRON PRP dobj
# , PUNCT , punct
# give VERB VB conj
# it PRON PRP dobj
# away ADV RB prt
# or CCONJ CC cc
# re VERB VB conj
# - VERB VB conj
# use VERB VB ccomp
# it PRON PRP dobj
# under ADP IN prep
# the DET DT det
# terms NOUN NNS pobj
#
#  SPACE _SP dep
# of ADP IN prep
# the DET DT det
# Project PROPN NNP compound
# Gutenberg PROPN NNP compound
# License PROPN NNP pobj
# included VERB VBD acl
# with ADP IN prep
# this DET DT det
# ebook NOUN NN pobj
# or CCONJ CC cc
# online NOUN NN conj
#
#  SPACE _SP dep
# at ADP IN prep
# www.gutenberg.org NUM CD pobj
# . PUNCT . punct
# If SCONJ IN mark
# you PRON PRP nsubjpass
# are AUX VBP auxpass
# not PART RB neg
# located VERB VBN advcl
# in ADP IN prep
# the DET DT det
# United PROPN NNP compound
# States PROPN NNP pobj
# , PUNCT , punct
#
#  SPACE _SP dep
# you PRON PRP nsubj
# will AUX MD aux
# have VERB VB ROOT
# to PART TO aux
# check VERB VB xcomp
# the DET DT det
# laws NOUN NNS dobj
# of ADP IN prep
# the DET DT det
# country NOUN NN pobj
# where SCONJ WRB advmod
# you PRON PRP nsubjpass
# are AUX VBP auxpass
# located VERB VBN relcl
#
#  SPACE _SP dep
# before ADP IN prep
# using VERB VBG pcomp
# this DET DT det
# eBook PROPN NNP dobj
# . PUNCT . punct
#
#
#  SPACE _SP dep
# Title NOUN NN ROOT
# : PUNCT : punct
# Hephæstus PROPN NNP appos
# ; PUNCT : punct
# or CCONJ CC cc
# , PUNCT , punct
# The DET DT det
# Soul PROPN NNP conj
# of ADP IN prep
# the DET DT det
# Machine PROPN NNP compound
#
#
#  SPACE _SP dep
# Author PROPN NNP pobj
# : PUNCT : punct
# Edmund PROPN NNP compound
# Edward PROPN NNP compound
# Fournier PROPN NNP compound
# d'Albe PROPN NNP compound
#
#
#  SPACE _SP dep
# Release PROPN NNP compound
# date NOUN NN appos
# : PUNCT : punct
# March PROPN NNP npadvmod
# 17 NUM CD nummod
# , PUNCT , punct
# 2024 NUM CD nummod
# [ X XX punct
# eBook PROPN NNP appos
# # SYM $ nmod
# 73186 NUM CD npadvmod
# ] PUNCT -RRB- punct
#
#
#  SPACE _SP dep
# Language NOUN NN appos
# : PUNCT : punct
# English PROPN NNP amod
#
#
#  SPACE _SP dep
# Original ADJ JJ amod
# publication NOUN NN appos
# : PUNCT : punct
# New PROPN NNP compound
# York PROPN NNP appos
# : PUNCT : punct
# E. PROPN NNP compound
# P. PROPN NNP compound
# Dutton PROPN NNP nsubjpass
# & CCONJ CC cc
# Company PROPN NNP conj
# , PUNCT , punct
# 1925 NUM CD nummod
#
#
#  SPACE _SP dep
# Credits NOUN NNS appos
# : PUNCT : punct
# Produced VERB VBN acl
# by ADP IN agent
# Tim PROPN NNP compound
# Lindell PROPN NNP pobj
# , PUNCT , punct
# Donald PROPN NNP compound
# Cummings PROPN NNP conj
# and CCONJ CC cc
# the DET DT det
# Online PROPN NNP compound
# Distributed VERB VBN amod
# Proofreading PROPN NNP compound
# Team PROPN NNP conj
# at ADP IN prep
# https://www.pgdp.net NOUN NNS pobj
# ( PUNCT -LRB- punct
# This DET DT det
# book NOUN NN nsubjpass
# was AUX VBD auxpass
# produced VERB VBN ROOT
# from ADP IN prep
# images NOUN NNS pobj
# made VERB VBN acl
# available ADJ JJ oprd
# by ADP IN agent
# the DET DT det
# HathiTrust PROPN NNP compound
# Digital PROPN NNP compound
# Library PROPN NNP pobj
# . PUNCT . punct
# ) PUNCT -RRB- punct
#
#
#
#  SPACE _SP dep
# * PUNCT NFP punct
# * PUNCT NFP punct
# * ADJ JJ punct
# START NOUN NN dep
# OF ADP IN prep
# THE DET DT det
# PROJECT PROPN NNP compound
# GUTENBERG PROPN NNP compound
# EBOOK VERB VBZ compound
# HEPHÆSTUS PROPN NNP pobj
# ; PUNCT : punct
# OR CCONJ CC cc
# , PUNCT , punct
# THE DET DT det
# SOUL PROPN NNP conj
# OF ADP IN prep
# THE DET DT det
# MACHINE PROPN NNP pobj
# * PROPN NNP punct
# * PUNCT NFP punct
# * PUNCT NFP punct
#
#
#
#
#
#
#                                 SPACE _SP dep
# HEPHÆSTUS PROPN NNP compound
#
#
#
#
#
#                                 SPACE _SP dep
# HEPHÆSTUS PROPN NNP appos
#
#
#                                    SPACE _SP dep
# OR CCONJ CC cc
#
#
#                          SPACE _SP dep
# The DET DT det
# Soul PROPN NNP conj
# of ADP IN prep
# the DET DT det
# Machine PROPN NNP pobj
#
#
#                                    SPACE _SP dep
# BY PROPN NNP compound
#
#                           SPACE _SP dep
# E. PROPN NNP compound
# E. PROPN NNP compound
# FOURNIER PROPN NNP nsubj
# D’ALBE NOUN NNS ROOT
#
#                      SPACE _SP dep
# _ PUNCT NFP punct
# Author NOUN NN ROOT
# of ADP IN prep
# “ PUNCT `` punct
# Quo PROPN NNP compound
# Vadimus PROPN NNP pobj
# , PUNCT , punct
# ” PUNCT '' punct
# etc X FW conj
# . X FW conj
# _ PUNCT NFP appos
#
#
#
#                              SPACE _SP dep
# [ X XX punct
# Illustration NOUN NN nmod
# ] PUNCT -RRB- punct
#
#
#
#                                 SPACE _SP dep
# NEW PROPN NNP compound
# YORK PROPN NNP compound
#
#                          SPACE _SP dep
# E. PROPN NNP compound
# P. PROPN NNP compound
# DUTTON PROPN NNP nmod
# & CCONJ CC cc
# COMPANY PROPN NNP conj
#
#                             SPACE _SP dep
# 681 NUM CD nummod
# FIFTH PROPN NNP compound
# AVENUE PROPN NNP compound
#
#
#
#
#
#                              SPACE _SP dep
# Copyright PROPN NNP ROOT
# , PUNCT , punct
# 1925 NUM CD npadvmod
#
#                         SPACE _SP dep
# By ADP IN prep
# E. PROPN NNP compound
# P. PROPN NNP compound
# DUTTON PROPN NNP pobj
# & CCONJ CC cc
# COMPANY PROPN NNP conj
#
#
#
#                           SPACE _SP dep
# _ PUNCT NFP punct
# All DET DT det
# Rights NOUN NNS npadvmod
# Reserved VERB VBN ROOT
# _ NOUN NN npadvmod
#
#
#
#                  SPACE _SP dep
# PRINTED VERB VBZ conj
# IN ADP IN prep
# THE DET DT det
# UNITED PROPN NNP compound
# STATES PROPN NNP pobj
# OF ADP IN prep
# AMERICA PROPN NNP compound
#
#
#
#
#
#                                  SPACE _SP dep
# PREFACE PROPN NNP pobj
#
#
#
#  SPACE _SP dep
# The DET DT det
# purpose NOUN NN nsubj
# of ADP IN prep
# this DET DT det
# little ADJ JJ amod
# book NOUN NN pobj
# is AUX VBZ ROOT
# to PART TO aux
# show VERB VB xcomp
# that SCONJ IN det
# one NUM CD dobj
# , PUNCT , punct
# at ADP IN advmod
# least ADJ JJS advmod
# , PUNCT , punct
# of ADP IN prep
#
#  SPACE _SP dep
# the DET DT det
# gods NOUN NNS nsubj
# of ADP IN prep
# Hellas PROPN NNP pobj
# has AUX VBZ aux
# survived VERB VBN pcomp
# the DET DT det
# flood NOUN NN dobj
# which PRON WDT nsubj
# swept VERB VBD relcl
# away ADV RB advmod
# the DET DT det
# most ADV RBS advmod
#
#  SPACE _SP dep
# entertaining ADJ JJ amod
# company NOUN NN dobj
# of ADP IN prep
# gods NOUN NNS pobj
# and CCONJ CC cc
# goddesses NOUN NNS conj
# ever ADV RB advmod
# created VERB VBN acl
# by ADP IN agent
# man NOUN NN nmod
# ’s PUNCT HYPH case
#
#  SPACE _SP dep
# imagination NOUN NN pobj
# . PUNCT . punct
# As SCONJ IN mark
# I PRON PRP nsubj
# propose VERB VBP advcl
# to PART TO aux
# set VERB VB xcomp
# him PRON PRP dobj
# in ADP IN prep
# the DET DT det
# august PROPN NNP compound
# place NOUN NN pobj
# vacated VERB VBN acl
# by ADP IN agent
# the DET DT det
#
#  SPACE _SP dep
# death NOUN NN pobj
# of ADP IN prep
# Zeus PROPN NNP pobj
# , PUNCT , punct
# a DET DT quantmod
# few ADJ JJ amod
# biographical ADJ JJ amod
# details NOUN NNS nsubj
# may AUX MD aux
# not PART RB neg
# be AUX VB ROOT
# out ADP IN prep
# of ADP IN prep
# place NOUN NN pobj
# . PUNCT . punct
#
#
#  SPACE _SP dep
# Hephæstus PROPN NNP nsubj
# was AUX VBD ROOT
# the DET DT det
# son NOUN NN attr
# of ADP IN prep
# Hera PROPN NNP pobj
# ( PUNCT -LRB- punct
# Juno PROPN NNP appos
# ) PUNCT -RRB- punct
# , PUNCT , punct
# but CCONJ CC cc
# not PART RB neg
# of ADP IN prep
# Zeus PROPN NNP pobj
# ( PUNCT -LRB- punct
# Jupiter PROPN NNP appos
# ) PUNCT -RRB- punct
# . PUNCT . punct
# How SCONJ WRB advmod
#
#  SPACE _SP dep
# his PRON PRP$ poss
# mother NOUN NN nsubj
# put VERB VBD csubj
# him PRON PRP dobj
# into ADP IN prep
# the DET DT det
# world NOUN NN pobj
# is AUX VBZ ROOT
# not PART RB neg
# precisely ADV RB advmod
# known ADJ JJ acomp
# . PUNCT . punct
# Neither DET DT det
# Zeus PROPN NNP nsubj
#
#  SPACE _SP dep
# nor CCONJ CC cc
# any DET DT det
# other ADJ JJ amod
# male NOUN NN compound
# god PROPN NNP nsubj
# had VERB VBD ROOT
# anything PRON NN dobj
# to PART TO aux
# do VERB VB relcl
# with ADP IN prep
# it PRON PRP pobj
# . PUNCT . punct
# Yet ADV RB cc
# it PRON PRP nsubj
# would AUX MD aux
# be AUX VB ROOT
#
#  SPACE _SP dep
# inappropriate ADJ JJ acomp
# in ADP IN prep
# the DET DT det
# case NOUN NN pobj
# of ADP IN prep
# such DET PDT predet
# a DET DT det
# confirmed ADJ JJ amod
# matron NOUN NN pobj
# as SCONJ IN mark
# Hera PROPN NNP nsubj
# to PART TO aux
# speak VERB VB advcl
#
#  SPACE _SP dep
# of ADP IN prep
# parthenogenesis NOUN NN pobj
# . PUNCT . punct
# Some DET DT det
# extraordinary ADJ JJ amod
# event NOUN NN nsubj
# had VERB VBD ROOT
# to PART TO aux
# take VERB VB xcomp
# place NOUN NN dobj
# before SCONJ IN mark
#
#  SPACE _SP dep
# the DET DT det
# great ADJ JJ amod
# home NOUN NN compound
# - PUNCT HYPH punct
# goddess NOUN NN nsubjpass
# could AUX MD aux
# be AUX VB auxpass
# driven VERB VBN advcl
# to PART TO aux
# spite VERB VB advcl
# her PRON PRP$ poss
# lord NOUN NN dobj
# and CCONJ CC cc
# master NOUN NN conj
#
#  SPACE _SP dep
# by ADP IN prep
# producing VERB VBG pcomp
# a DET DT det
# son NOUN NN dobj
# without ADP IN prep
# his PRON PRP$ poss
# co NOUN NN pobj
# - NOUN NN pobj
# operation NOUN NN pobj
# . PUNCT . punct
# And CCONJ CC cc
# such DET PDT predet
# an DET DT det
# event NOUN NN nsubj
# had AUX VBD aux
#
#  SPACE _SP dep
# indeed ADV RB advmod
# occurred VERB VBD ROOT
# , PUNCT , punct
# for SCONJ IN mark
# Zeus PROPN NNP nsubj
# had AUX VBD aux
# suddenly ADV RB advmod
# reverted VERB VBN advcl
# to ADP IN prep
# one NUM CD pobj
# of ADP IN prep
# the DET DT det
# oldest ADJ JJS amod
#
#  SPACE _SP dep
# forms NOUN NNS pobj
# of ADP IN prep
# propagation NOUN NN pobj
# known VERB VBN acl
# to ADP IN prep
# biology NOUN NN pobj
# , PUNCT , punct
# _ PROPN NNP compound
# viz PROPN NNP appos
# . PUNCT . punct
# _ PROPN NNP ROOT
# , PUNCT , punct
# propagation NOUN NN appos
# by ADP IN prep
# budding VERB VBG pcomp
# . PUNCT . punct
#
#  SPACE _SP dep
# A DET DT det
# fully ADV RB advmod
# - PUNCT HYPH punct
# armed VERB VBN amod
# young ADJ JJ amod
# goddess NOUN NN nsubj
# , PUNCT , punct
# severe ADJ JJ amod
# of ADP IN prep
# countenance NOUN NN pobj
# and CCONJ CC cc
# lithe NOUN NN conj
# of ADP IN prep
# limb NOUN NN pobj
# , PUNCT , punct
#
#  SPACE _SP dep
# had AUX VBD aux
# sprung VERB VBN ROOT
# forth ADV RB advmod
# from ADP IN prep
# his PRON PRP$ poss
# head NOUN NN pobj
# , PUNCT , punct
# thenceforth NOUN NN conj
# and CCONJ CC cc
# for ADP IN conj
# ever ADV RB pcomp
# to PART TO aux
# lead VERB VB advcl
# and CCONJ CC cc
#
#  SPACE _SP dep
# dominate VERB VB conj
# the DET DT det
# world NOUN NN dobj
# of ADP IN prep
# thought NOUN NN pobj
# . PUNCT . punct
# It PRON PRP nsubj
# was AUX VBD ROOT
# up ADP IN prep
# to ADP IN prep
# Hera PROPN NNP pobj
# to PART TO aux
# match VERB VB xcomp
# Pallas PROPN NNP compound
# Athene PROPN NNP dobj
#
#  SPACE _SP dep
# by ADP IN prep
# some DET DT det
# equally ADV RB advmod
# important ADJ JJ amod
# contribution NOUN NN pobj
# to ADP IN prep
# the DET DT det
# evolution NOUN NN pobj
# of ADP IN prep
# gods NOUN NNS pobj
# , PUNCT , punct
# and CCONJ CC cc
#
#  SPACE _SP dep
# so ADV RB advmod
# by ADP IN prep
# some DET DT det
# mysterious ADJ JJ amod
# process NOUN NN pobj
# , PUNCT , punct
# into ADP IN prep
# which PRON WDT pobj
# Greek ADJ JJ amod
# historians NOUN NNS nsubj
# did AUX VBD aux
# not PART RB neg
# care VERB VB relcl
#
#  SPACE _SP dep
# to ADP IN prep
# pry PROPN NNP pobj
# , PUNCT , punct
# she PRON PRP nsubj
# produced VERB VBD conj
# Hephæstus PROPN NNP dobj
# , PUNCT , punct
# whom PRON WP dobj
# the DET DT det
# Romans PROPN NNPS nsubj
# called VERB VBD relcl
# Vulcan PROPN NNP oprd
# , PUNCT , punct
# now ADV RB advmod
# the DET DT det
#
#  SPACE _SP dep
# only ADV RB advmod
# surviving VERB VBG amod
# representative NOUN NN appos
# of ADP IN prep
# that DET DT det
# lively ADJ JJ amod
# and CCONJ CC cc
# enterprising ADJ JJ conj
# clan NOUN NN pobj
#
#  SPACE _SP dep
# which PRON WDT nsubj
# once ADV RB advmod
# ruled VERB VBD relcl
# the DET DT det
# world NOUN NN dobj
# from ADP IN prep
# the DET DT det
# summit NOUN NN pobj
# of ADP IN prep
# Mount PROPN NNP compound
# Olympus PROPN NNP pobj
# . PUNCT . punct
#
#
#  SPACE _SP dep
# Like ADP IN prep
# many ADJ JJ amod
# another DET DT det
# product NOUN NN pobj
# of ADP IN prep
# inspiration NOUN NN pobj
# , PUNCT , punct
# Hephæstus PROPN NNP nsubj
# was AUX VBD ROOT
# at ADP IN prep
# first ADJ JJ advmod
#
#  SPACE _SP dep
# regarded VERB VBN pcomp
# as ADP IN prep
# a DET DT det
# failure NOUN NN pobj
# . PUNCT . punct
# He PRON PRP nsubj
# was AUX VBD ROOT
# undersized ADJ JJ acomp
# and CCONJ CC cc
# weak ADJ JJ advmod
# - PUNCT HYPH punct
# chested VERB VBN conj
# , PUNCT , punct
# and CCONJ CC cc
# Hera PROPN NNP nsubj
#
#  SPACE _SP dep
# had VERB VBD conj
# to PART TO aux
# suffer VERB VB xcomp
# much ADV RB advmod
# from ADP IN prep
# the DET DT det
# gibes NOUN NNS pobj
# of ADP IN prep
# her PRON PRP$ poss
# peers NOUN NNS pobj
# and CCONJ CC cc
# peeresses NOUN NNS conj
# . PUNCT . punct
# So ADV RB advmod
#
#  SPACE _SP dep
# one NUM CD nummod
# day NOUN NN npadvmod
# she PRON PRP nsubj
# dropped VERB VBD ROOT
# him PRON PRP dobj
# down ADP IN prep
# the DET DT det
# slope NOUN NN pobj
# of ADP IN prep
# the DET DT det
# mountain NOUN NN pobj
# and CCONJ CC cc
# he PRON PRP nsubj
# fell VERB VBD conj
#
#  SPACE _SP dep
# into ADP IN prep
# the DET DT det
# sea NOUN NN pobj
# . PUNCT . punct
# He PRON PRP nsubjpass
# was AUX VBD auxpass
# picked VERB VBN ROOT
# up ADP RP prt
# by ADP IN agent
# two NUM CD pobj
# of ADP IN prep
# those DET DT det
# charming ADJ JJ amod
# and CCONJ CC cc
# motherly ADJ JJ conj
#
#  SPACE _SP dep
# sea NOUN NN compound
# - PUNCT HYPH punct
# goddesses NOUN NNS pobj
# which PRON WDT nsubj
# at ADP IN prep
# that DET DT det
# time NOUN NN pobj
# abounded VERB VBD relcl
# in ADP IN prep
# sea NOUN NN compound
# - PUNCT HYPH punct
# water NOUN NN pobj
# , PUNCT , punct
# and CCONJ CC cc
# was AUX VBD auxpass
#
#  SPACE _SP dep
# brought VERB VBN conj
# up ADP RP prt
# in ADP IN prep
# a DET DT det
# grotto NOUN NN pobj
# under ADP IN prep
# the DET DT det
# ocean NOUN NN pobj
# . PUNCT . punct
# In ADP IN prep
# return NOUN NN pobj
# for ADP IN prep
# their PRON PRP$ poss
# kindnesses NOUN NNS pobj
#
#  SPACE _SP dep
# he PRON PRP nsubj
# made VERB VBD ROOT
# them PRON PRP nsubj
# pretty ADJ JJ amod
# ornaments NOUN NNS ccomp
# of ADP IN prep
# coral ADJ JJ pobj
# and CCONJ CC cc
# mother NOUN NN conj
# - PUNCT HYPH punct
# of ADP IN prep
# - PUNCT HYPH punct
# pearl NOUN NN pobj
# . PUNCT . punct
#
#
#  SPACE _SP dep
# At ADP IN prep
# the DET DT det
# age NOUN NN pobj
# of ADP IN prep
# ten NUM CD pobj
# , PUNCT , punct
# or CCONJ CC cc
# thereabouts NOUN NNS conj
# , PUNCT , punct
# he PRON PRP nsubj
# set VERB VBD ROOT
# out ADP RP prt
# to PART TO aux
# find VERB VB xcomp
# his PRON PRP$ poss
# mother NOUN NN dobj
# . PUNCT . punct
# It PRON PRP nsubj
#
#  SPACE _SP dep
# was AUX VBD ccomp
# some DET DT det
# time NOUN NN attr
# before SCONJ IN mark
# Hera PROPN NNP nsubj
# recognized VERB VBD advcl
# in ADP IN prep
# the DET DT det
# lame ADJ JJ amod
# boy NOUN NN pobj
# , PUNCT , punct
# with ADP IN prep
# the DET DT det
# spinal ADJ JJ amod
#
#  SPACE _SP dep
# curvature NOUN NN pobj
# and CCONJ CC cc
# the DET DT det
# swarthy NOUN NN conj
# but CCONJ CC cc
# pleasant ADJ JJ amod
# face NOUN NN conj
# , PUNCT , punct
# the DET DT det
# child NOUN NN nsubj
# she PRON PRP nsubj
# had VERB VBD relcl
# so ADV RB advmod
#
#  SPACE _SP dep
# mercilessly ADV RB advmod
# cast VERB VBN ROOT
# off ADP RP prt
# . PUNCT . punct
# But CCONJ CC cc
# a DET DT det
# spark NOUN NN nsubj
# of ADP IN prep
# mother NOUN NN compound
# - PUNCT HYPH punct
# instinct NOUN NN pobj
# revived VERB VBD ROOT
# under ADP IN prep
# the DET DT det
#
#  SPACE _SP dep
# flame NOUN NN pobj
# of ADP IN prep
# the DET DT det
# child NOUN NN poss
# ’s PART POS case
# filial ADJ JJ amod
# devotion NOUN NN pobj
# , PUNCT , punct
# and CCONJ CC cc
# they PRON PRP nsubj
# soon ADV RB advmod
# became VERB VBD conj
# lasting VERB VBG amod
#
#  SPACE _SP dep
# friends NOUN NNS attr
# and CCONJ CC cc
# allies NOUN NNS conj
# . PUNCT . punct
#
#
#  SPACE _SP dep
# Hephæstus PROPN NNP nsubj
# , PUNCT , punct
# naturally ADV RB advmod
# , PUNCT , punct
# owed VERB VBD ROOT
# no DET DT det
# allegiance NOUN NN dobj
# to ADP IN dative
# Zeus PROPN NNP pobj
# , PUNCT , punct
# and CCONJ CC cc
# in ADP IN prep
# the DET DT det
# frequent ADJ JJ amod
#
#  SPACE _SP dep
# marital ADJ JJ amod
# disputes NOUN NNS pobj
# between ADP IN prep
# him PRON PRP pobj
# and CCONJ CC cc
# Hera PROPN NNP conj
# he PRON PRP nsubj
# invariably ADV RB advmod
# took VERB VBD conj
# his PRON PRP$ poss
# mother NOUN NN poss
# ’s PART POS case
#
#  SPACE _SP dep
# part NOUN NN dobj
# , PUNCT , punct
# and CCONJ CC cc
# so ADV RB advmod
# successfully ADV RB advmod
# that SCONJ IN mark
# the DET DT det
# redoubtable ADJ JJ amod
# Father PROPN NNP nsubj
# of ADP IN prep
# the DET DT det
# Gods PROPN NNPS pobj
#
#  SPACE _SP dep
# took VERB VBD conj
# him PRON PRP dobj
# by ADP IN prep
# his PRON PRP$ poss
# lame ADJ JJ amod
# leg NOUN NN pobj
# and CCONJ CC cc
# flung VERB VBD conj
# him PRON PRP dobj
# into ADP IN prep
# space NOUN NN pobj
# . PUNCT . punct
# He PRON PRP nsubj
# fell VERB VBD ROOT
# for ADP IN prep
# a DET DT det
# whole ADJ JJ amod
#
#  SPACE _SP dep
# day[1 NOUN NNS pobj
# ] PUNCT -RRB- punct
# and CCONJ CC cc
# eventually ADV RB advmod
# alighted VERB VBN conj
# , PUNCT , punct
# like ADP IN prep
# a DET DT det
# meteorite NOUN NN pobj
# , PUNCT , punct
# on ADP IN prep
# the DET DT det
# island NOUN NN pobj
# of ADP IN prep
#
#  SPACE _SP dep
# Lemnos PROPN NNP pobj
# , PUNCT , punct
# where SCONJ WRB advmod
# he PRON PRP nsubjpass
# was AUX VBD auxpass
# worshipped VERB VBN relcl
# as ADV RB advmod
# many ADJ JJ amod
# a DET DT det
# meteorite NOUN NN dobj
# has AUX VBZ aux
# been AUX VBN auxpass
# worshipped VERB VBN conj
#
#  SPACE _SP dep
# before ADV RB advmod
# and CCONJ CC cc
# since ADV RB conj
# . PUNCT . punct
# He PRON PRP nsubj
# put VERB VBD ROOT
# up ADP RP prt
# with ADP IN prep
# this PRON DT pobj
# for ADP IN prep
# a DET DT det
# while NOUN NN pobj
# , PUNCT , punct
# but CCONJ CC cc
# the DET DT det
# blood NOUN NN nsubj
# of ADP IN prep
# the DET DT det
#
#  SPACE _SP dep
# Olympians PROPN NNPS pobj
# asserted VERB VBD conj
# itself PRON PRP dobj
# , PUNCT , punct
# and CCONJ CC cc
# he PRON PRP nsubj
# painfully ADV RB advmod
# climbed VERB VBD conj
# home ADV RB advmod
# once ADV RB advmod
# more ADV RBR advmod
# . PUNCT . punct
#
#  SPACE _SP dep
# This DET DT det
# time NOUN NN npadvmod
# he PRON PRP nsubj
# succeeded VERB VBD relcl
# in ADP IN prep
# planting VERB VBG pcomp
# his PRON PRP$ poss
# unequal ADJ JJ amod
# feet NOUN NNS dobj
# firmly ADV RB advmod
# on ADP IN prep
# his PRON PRP$ poss
#
#  SPACE _SP dep
# native ADJ JJ amod
# rock NOUN NN pobj
# , PUNCT , punct
# and CCONJ CC cc
# he PRON PRP nsubj
# soon ADV RB advmod
# became VERB VBD ROOT
# a DET DT det
# favourite NOUN NN attr
# among ADP IN prep
# his PRON PRP$ poss
# divine ADJ JJ amod
# relations NOUN NNS pobj
# . PUNCT . punct
#
#  SPACE _SP dep
# He PRON PRP nsubj
# undertook VERB VBD ROOT
# the DET DT det
# reconstruction NOUN NN dobj
# of ADP IN prep
# the DET DT det
# Olympian ADJ JJ amod
# dwellings NOUN NNS pobj
# , PUNCT , punct
# and CCONJ CC cc
# for ADP IN prep
# this DET DT det
#
#  SPACE _SP dep
# purpose NOUN NN nsubj
# established VERB VBD conj
# a DET DT det
# wonderful ADJ JJ amod
# workshop NOUN NN dobj
# with ADP IN prep
# a DET DT det
# huge ADJ JJ amod
# anvil NOUN NN pobj
# and CCONJ CC cc
# twenty NUM CD conj
#
#  SPACE _SP dep
# bellows VERB VBZ conj
# , PUNCT , punct
# all PRON DT nsubj
# of ADP IN prep
# which PRON WDT pobj
# would AUX MD aux
# work VERB VB relcl
# at ADP IN prep
# his PRON PRP$ poss
# mere ADJ JJ amod
# behest NOUN NN pobj
# . PUNCT . punct
# The DET DT det
# workshop NOUN NN nsubjpass
# was AUX VBD auxpass
#
#  SPACE _SP dep
# made VERB VBN ROOT
# of ADP IN prep
# fire NOUN NN npadvmod
# - PUNCT HYPH punct
# proof ADJ JJ amod
# materials NOUN NNS pobj
# , PUNCT , punct
# and CCONJ CC cc
# shone VERB VBD conj
# “ PUNCT `` punct
# like ADP IN prep
# a DET DT det
# star NOUN NN pobj
# in ADP IN prep
# the DET DT det
# night NOUN NN pobj
# . PUNCT . punct
# ” PUNCT '' punct
#
#
#    SPACE _SP dep
# [ X XX dep
# 1 X LS dep
# ] PUNCT -RRB- dep
# This PRON DT nsubj
# must AUX MD aux
# be AUX VB ROOT
# a DET DT det
# mistake NOUN NN attr
# , PUNCT , punct
# as SCONJ IN mark
# it PRON PRP nsubj
# would AUX MD aux
# put VERB VB advcl
# the DET DT det
# summit NOUN NN dobj
# of ADP IN prep
# Olympus PROPN NNP pobj
#
#        SPACE _SP dep
# somewhere ADV RB advmod
# beyond ADP IN prep
# the DET DT det
# orbit NOUN NN pobj
# of ADP IN prep
# the DET DT det
# moon NOUN NN pobj
# . PUNCT . punct
#
#
#  SPACE _SP dep
# He PRON PRP nsubj
# solved VERB VBD ROOT
# the DET DT det
# housing NOUN NN compound
# question NOUN NN dobj
# by ADP IN prep
# building VERB VBG pcomp
# a DET DT det
# separate ADJ JJ amod
# palace NOUN NN dobj
# for ADP IN prep
#
#  SPACE _SP dep
# each PRON DT pobj
# of ADP IN prep
# the DET DT det
# gods NOUN NNS pobj
# and CCONJ CC cc
# goddesses NOUN NNS conj
# , PUNCT , punct
# replete ADJ JJ conj
# with ADP IN prep
# all DET PDT predet
# the DET DT det
# comforts NOUN NNS pobj
# and CCONJ CC cc
#
#  SPACE _SP dep
# refinements NOUN NNS conj
# of ADP IN prep
# civilization NOUN NN pobj
# . PUNCT . punct
# Nor CCONJ CC cc
# did AUX VBD aux
# his PRON PRP$ poss
# amiability NOUN NN nsubj
# end VERB VB ROOT
# there ADV RB advmod
# . PUNCT . punct
#
#  SPACE _SP dep
# Sometimes ADV RB advmod
# , PUNCT , punct
# at ADP IN prep
# their PRON PRP$ poss
# daily ADJ JJ amod
# assemblies NOUN NNS pobj
# , PUNCT , punct
# he PRON PRP nsubj
# would AUX MD aux
# give VERB VB ROOT
# Ganymede PROPN NNP dative
# a DET DT det
# day NOUN NN dobj
# off ADV RB prt
#
#  SPACE _SP dep
# and CCONJ CC cc
# would AUX MD aux
# himself PRON PRP nsubj
# hand VERB VB conj
# round VERB VB xcomp
# the DET DT det
# nectar NOUN NN dobj
# , PUNCT , punct
# producing VERB VBG advcl
# roars NOUN NNS dobj
# of ADP IN prep
# laughter NOUN NN pobj
#
#  SPACE _SP dep
# by ADP IN prep
# the DET DT det
# contrast NOUN NN pobj
# between ADP IN prep
# his PRON PRP$ poss
# hobbling VERB VBG amod
# gait NOUN NN pobj
# and CCONJ CC cc
# the DET DT det
# deportment NOUN NN conj
# of ADP IN prep
# the DET DT det
#
#  SPACE _SP dep
# graceful ADJ JJ amod
# young ADJ JJ amod
# cup NOUN NN compound
# - PUNCT HYPH punct
# bearer NOUN NN pobj
# . PUNCT . punct
#
#
#  SPACE _SP dep
# He PRON PRP nsubj
# became VERB VBD ROOT
# so ADV RB advmod
# popular ADJ JJ acomp
# that SCONJ IN mark
# at ADP IN prep
# last ADJ JJ pcomp
# he PRON PRP nsubj
# was AUX VBD ccomp
# able ADJ JJ acomp
# to PART TO aux
# marry VERB VB xcomp
# Aphrodite PROPN NNP dobj
#
#  SPACE _SP dep
# herself PRON PRP dobj
# , PUNCT , punct
# the DET DT det
# goddess NOUN NN appos
# of ADP IN prep
# Love PROPN NNP pobj
# and CCONJ CC cc
# Beauty PROPN NNP conj
# , PUNCT , punct
# whom PRON WP dobj
# the DET DT det
# Romans PROPN NNPS nsubj
# called VERB VBN relcl
# Venus PROPN NNP oprd
# , PUNCT , punct
#
#  SPACE _SP dep
# and CCONJ CC cc
# who PRON WP nsubjpass
# was AUX VBD auxpass
# born VERB VBN conj
# of ADP IN prep
# the DET DT det
# foam NOUN NN pobj
# of ADP IN prep
# the DET DT det
# sea NOUN NN pobj
# somewhere ADV RB advmod
# off ADP IN prep
# Cyprus PROPN NNP pobj
# . PUNCT . punct
# But CCONJ CC cc
# this DET DT det
#
#  SPACE _SP dep
# union NOUN NN nsubj
# of ADP IN prep
# Beauty PROPN NNP pobj
# and CCONJ CC cc
# the DET DT det
# Beast PROPN NNP conj
# was AUX VBD ROOT
# far ADV RB advmod
# from ADP IN prep
# being AUX VBG pcomp
# a DET DT det
# happy ADJ JJ amod
# one NOUN NN attr
# . PUNCT . punct
# Venus PROPN NNP nsubj
# was AUX VBD ROOT
#
#  SPACE _SP dep
# not PART RB neg
# satisfied ADJ JJ acomp
# with ADP IN prep
# a DET DT det
# “ PUNCT `` punct
# lame ADJ JJ amod
# mechanic NOUN NN pobj
# ” PUNCT '' punct
# as SCONJ IN mark
# she PRON PRP nsubj
# called VERB VBD advcl
# him PRON PRP dobj
# , PUNCT , punct
# and CCONJ CC cc
# hankered VERB VBD conj
#
#  SPACE _SP dep
# after ADP IN prep
# the DET DT det
# dashing VERB VBG amod
# Ares PROPN NNPS pobj
# , PUNCT , punct
# alias NOUN NNS compound
# Mars PROPN NNP npadvmod
# , PUNCT , punct
# the DET DT det
# god NOUN NN appos
# of ADP IN prep
# war NOUN NN pobj
# . PUNCT . punct
# Having AUX VBG aux
# been AUX VBN auxpass
# warned VERB VBN advcl
#
#  SPACE _SP dep
# by ADP IN agent
# Helios PROPN NNP pobj
# , PUNCT , punct
# the DET DT det
# sun NOUN NN nsubj
# - PUNCT HYPH punct
# god PROPN NNP appos
# , PUNCT , punct
# of ADP IN prep
# the DET DT det
# progress NOUN NN pobj
# of ADP IN prep
# the DET DT det
# intrigue――after NOUN NN pobj
# it PRON PRP nsubj
# had AUX VBD aux
#
#  SPACE _SP dep
# already ADV RB advmod
# reached VERB VBN relcl
# its PRON PRP$ poss
# climax――Hephæstus NOUN NN dobj
# lay VERB VB ccomp
# in ADP IN prep
# wait NOUN NN pobj
# for ADP IN prep
# the DET DT det
# guilty ADJ JJ amod
# pair NOUN NN pobj
#
#  SPACE _SP dep
# with ADP IN prep
# an DET DT det
# invisible ADJ JJ amod
# net NOUN NN pobj
# , PUNCT , punct
# and CCONJ CC cc
# having AUX VBG aux
# caught VERB VBN conj
# them PRON PRP dobj
# , PUNCT , punct
# dragged VERB VBD ROOT
# them PRON PRP dobj
# before ADP IN prep
# the DET DT det
#
#  SPACE _SP dep
# other ADJ JJ amod
# gods NOUN NNS pobj
# amid ADP IN prep
# Homeric PROPN NNP compound
# laughter NOUN NN pobj
# produced VERB VBN acl
# by ADP IN agent
# their PRON PRP$ poss
# struggles NOUN NNS pobj
# in ADP IN prep
# the DET DT det
#
#  SPACE _SP dep
# invisible ADJ JJ amod
# meshes NOUN NNS pobj
# . PUNCT . punct
# And CCONJ CC cc
# when SCONJ WRB advmod
# a DET DT det
# daughter NOUN NN nsubjpass
# was AUX VBD auxpass
# born VERB VBN advcl
# , PUNCT , punct
# whom PRON WP dobj
# they PRON PRP nsubj
# miscalled VERB VBD advcl
#
#  SPACE _SP dep
# Harmonia PROPN NNP dobj
# , PUNCT , punct
# Hephæstus PROPN NNP nsubj
# had VERB VBD ROOT
# his PRON PRP$ poss
# revenge NOUN NN dobj
# by ADP IN prep
# presenting VERB VBG pcomp
# her PRON PRP dobj
# with ADP IN prep
# a DET DT det
# necklace NOUN NN pobj
#
#  SPACE _SP dep
# which PRON WDT nsubj
# brought VERB VBD relcl
# disaster NOUN NN dobj
# to ADP IN dative
# her PRON PRP pobj
# and CCONJ CC cc
# all DET PDT predet
# its PRON PRP$ poss
# later ADJ JJ amod
# possessors NOUN NNS conj
# until SCONJ IN mark
# it PRON PRP nsubjpass
#
#  SPACE _SP dep
# was AUX VBD auxpass
# finally ADV RB advmod
# laid VERB VBN advcl
# to AUX IN aux
# rest VERB VB xcomp
# in ADP IN prep
# the DET DT det
# temple NOUN NN pobj
# of ADP IN prep
# Athene PROPN NNP pobj
# . PUNCT . punct
#
#
#  SPACE _SP dep
# Meanwhile ADV RB advmod
# , PUNCT , punct
# the DET DT det
# fame NOUN NN nsubj
# of ADP IN prep
# his PRON PRP$ poss
# works NOUN NNS pobj
# spread VERB VBP ROOT
# far ADV RB advmod
# and CCONJ CC cc
# wide ADJ JJ conj
# . PUNCT . punct
# King PROPN NNP compound
# Aetes PROPN NNP nsubj
#
#  SPACE _SP dep
# of ADP IN prep
# Colchis PROPN NNP pobj
# ordered VERB VBD ROOT
# the DET DT det
# construction NOUN NN dobj
# of ADP IN prep
# two NUM CD nummod
# bronze NOUN NN compound
# bulls NOUN NNS pobj
# capable ADJ JJ amod
# of ADP IN prep
#
#  SPACE _SP dep
# breathing NOUN NN compound
# fire NOUN NN pobj
# through ADP IN prep
# their PRON PRP$ poss
# nostrils NOUN NNS pobj
# , PUNCT , punct
# and CCONJ CC cc
# when SCONJ WRB advmod
# Achilles PROPN NNP nsubj
# , PUNCT , punct
# the DET DT det
# Greek ADJ JJ amod
#
#  SPACE _SP dep
# champion NOUN NN appos
# before ADP IN prep
# Troy PROPN NNP pobj
# , PUNCT , punct
# decided VERB VBD advcl
# to PART TO aux
# kill VERB VB xcomp
# Hector PROPN NNP dobj
# and CCONJ CC cc
# avenge VERB VB conj
# his PRON PRP$ poss
# friend NOUN NN compound
#
#  SPACE _SP dep
# Patroclus PROPN NNP dobj
# , PUNCT , punct
# he PRON PRP nsubj
# went VERB VBD conj
# to ADP IN prep
# Hephæstus PROPN NNP pobj
# with ADP IN prep
# an DET DT det
# introduction NOUN NN pobj
# from ADP IN prep
# Thetis PROPN NNP pobj
# , PUNCT , punct
# the DET DT det
#
#  SPACE _SP dep
# sea NOUN NN compound
# - PUNCT HYPH punct
# goddess NOUN NN conj
# , PUNCT , punct
# and CCONJ CC cc
# prevailed VERB VBD conj
# upon SCONJ IN prep
# him PRON PRP pobj
# to PART TO aux
# make VERB VB xcomp
# him PRON PRP nsubj
# a DET DT det
# marvellous ADJ JJ amod
# shield NOUN NN ccomp
# on ADP IN prep
#
#  SPACE _SP dep
# which PRON WDT dobj
# all DET DT det
# heaven PROPN NNP nsubjpass
# and CCONJ CC cc
# earth NOUN NN conj
# were AUX VBD auxpass
# figured VERB VBN pcomp
# in ADP IN prep
# bronze NOUN NN pobj
# , PUNCT , punct
# and CCONJ CC cc
# which PRON WDT nsubj
# was AUX VBD conj
# quite ADV RB advmod
#
#  SPACE _SP dep
# impervious ADJ JJ acomp
# to ADP IN prep
# mortal ADJ JJ amod
# spear NOUN NN pobj
# and CCONJ CC cc
# battle NOUN NN compound
# - PUNCT HYPH punct
# axe NOUN NN conj
# . PUNCT . punct
#
#
#  SPACE _SP dep
# And CCONJ CC cc
# so ADV RB advmod
# he PRON PRP nsubj
# dwelt VERB VBP ROOT
# and CCONJ CC cc
# worked VERB VBD conj
# on ADP IN prep
# Olympus PROPN NNP pobj
# for ADP IN prep
# three NUM CD compound
# thousand NUM CD nummod
# years NOUN NNS pobj
# or CCONJ CC cc
# so ADV RB nummod
# , PUNCT , punct
#
#  SPACE _SP dep
# establishing VERB VBG advcl
# branch NOUN NN compound
# works NOUN NNS dobj
# on ADP IN prep
# Lipari PROPN NNP pobj
# and CCONJ CC cc
# in ADP IN conj
# Sicily PROPN NNP pobj
# which PRON WDT nsubj
# kept VERB VBD advcl
# working VERB VBG xcomp
#
#  SPACE _SP dep
# at ADP IN prep
# full ADJ JJ amod
# blast NOUN NN pobj
# until SCONJ IN mark
# Paul PROPN NNP nsubj
# of ADP IN prep
# Tarsus PROPN NNP pobj
# came VERB VBD advcl
# with ADP IN prep
# his PRON PRP$ poss
# claim NOUN NN pobj
# to PART TO aux
# have AUX VB aux
# found VERB VBN acl
#
#  SPACE _SP dep
# the DET DT det
# Unknown ADJ JJ amod
# God PROPN NNP dobj
# who PRON WP nsubj
# was AUX VBD relcl
# to PART TO aux
# establish VERB VB xcomp
# a DET DT det
# new ADJ JJ amod
# Roman ADJ JJ amod
# dominion NOUN NN dobj
# to PART TO aux
# take VERB VB advcl
# the DET DT det
#
#  SPACE _SP dep
# place NOUN NN dobj
# of ADP IN prep
# the DET DT det
# mighty PROPN NNP amod
# Empire PROPN NNP pobj
# of ADP IN prep
# the DET DT det
# Cæsars PROPN NNP pobj
# , PUNCT , punct
# and CCONJ CC cc
# was AUX VBD conj
# incidentally ADV RB acomp
# to PART TO aux
# sweep VERB VB xcomp
#
#  SPACE _SP dep
# away ADP RP prt
# the DET DT det
# gods NOUN NNS dobj
# of ADP IN prep
# Rome PROPN NNP pobj
# and CCONJ CC cc
# Greece PROPN NNP conj
# alike ADV RB advmod
# and CCONJ CC cc
# establish VERB VB conj
# the DET DT det
# worship NOUN NN dobj
# of ADP IN prep
# a DET DT det
#
#  SPACE _SP dep
# tripartite ADJ JJ amod
# God PROPN NNP pobj
# who PRON WP nsubj
# never ADV RB neg
# smiled VERB VBD relcl
# . PUNCT . punct
#
#
#  SPACE _SP dep
# So ADV RB advmod
# the DET DT det
# light ADJ JJ amod
# - PUNCT HYPH punct
# hearted ADJ JJ amod
# company NOUN NN nsubj
# of ADP IN prep
# Mount PROPN NNP compound
# Olympus PROPN NNP pobj
# died VERB VBD ROOT
# , PUNCT , punct
# all PRON DT dep
# but CCONJ CC cc
# Hephæstus PROPN NNP pobj
# , PUNCT , punct
#
#  SPACE _SP dep
# who PRON WP nsubj
# hobbled VERB VBD relcl
# through ADP IN prep
# many ADJ JJ amod
# lands NOUN NNS pobj
# seeking VERB VBG advcl
# a DET DT det
# place NOUN NN dobj
# where SCONJ WRB advmod
# he PRON PRP nsubj
# might AUX MD aux
# work VERB VB relcl
# and CCONJ CC cc
#
#  SPACE _SP dep
# set VERB VBD conj
# his PRON PRP$ poss
# bellows NOUN NNS dobj
# blowing VERB VBG advcl
# once ADV RB advmod
# more ADV RBR advmod
# . PUNCT . punct
# For ADP IN prep
# centuries NOUN NNS pobj
# he PRON PRP nsubj
# wandered VERB VBD relcl
# , PUNCT , punct
# despised VERB VBN ROOT
#
#  SPACE _SP dep
# and CCONJ CC cc
# jeered VERB VBD conj
# at ADP IN prep
# by ADP IN agent
# monks NOUN NNS pobj
# , PUNCT , punct
# hermits NOUN NNS conj
# , PUNCT , punct
# and CCONJ CC cc
# anchorites NOUN NNS conj
# . PUNCT . punct
# But CCONJ CC cc
# his PRON PRP$ poss
# courage NOUN NN nsubj
# never ADV RB neg
#
#  SPACE _SP dep
# failed VERB VBD ROOT
# him PRON PRP dobj
# . PUNCT . punct
# It PRON PRP nsubj
# survived VERB VBD ROOT
# the DET DT det
# desolation NOUN NN dobj
# of ADP IN prep
# the DET DT det
# Olympian ADJ JJ amod
# palaces NOUN NNS pobj
# as SCONJ IN mark
# it PRON PRP nsubj
#
#  SPACE _SP dep
# had AUX VBD aux
# survived VERB VBN advcl
# his PRON PRP$ poss
# two NUM CD nummod
# falls NOUN NNS dobj
# from ADP IN prep
# the DET DT det
# summit NOUN NN pobj
# . PUNCT . punct
#
#
#  SPACE _SP dep
# And CCONJ CC cc
# now ADV RB advmod
# he PRON PRP nsubj
# has AUX VBZ aux
# come VERB VBN ROOT
# back ADV RB advmod
# into ADP IN prep
# his PRON PRP$ poss
# own ADJ JJ pobj
# , PUNCT , punct
# and CCONJ CC cc
# his PRON PRP$ poss
# power NOUN NN nsubj
# is AUX VBZ aux
# spreading VERB VBG conj
# like ADP IN prep
#
#  SPACE _SP dep
# a DET DT det
# conflagration NOUN NN pobj
# . PUNCT . punct
# The DET DT det
# God PROPN NNP nsubj
# of ADP IN prep
# Fire PROPN NNP pobj
# is AUX VBZ ROOT
# the DET DT det
# supreme ADJ JJ amod
# master NOUN NN attr
# of ADP IN prep
# the DET DT det
# earth NOUN NN pobj
# . PUNCT . punct
#
#  SPACE _SP dep
# His PRON PRP$ poss
# furnaces NOUN NNS nsubj
# are AUX VBP aux
# roaring VERB VBG ROOT
# . PUNCT . punct
# He PRON PRP nsubj
# has AUX VBZ aux
# dispelled VERB VBN ROOT
# the DET DT det
# clouds NOUN NNS dobj
# of ADP IN prep
# Asiatic PROPN NNP amod
#
#  SPACE _SP dep
# mysticism NOUN NN pobj
# which PRON WDT nsubj
# obscured VERB VBD relcl
# his PRON PRP$ poss
# native ADJ JJ amod
# mountain NOUN NN dobj
# . PUNCT . punct
# He PRON PRP nsubj
# has AUX VBZ aux
# girdled VERB VBN ROOT
# the DET DT det
# world NOUN NN dobj
#
#  SPACE _SP dep
# with ADP IN prep
# hoops NOUN NNS pobj
# of ADP IN prep
# steel NOUN NN pobj
# . PUNCT . punct
# He PRON PRP nsubj
# has AUX VBZ aux
# found VERB VBN ROOT
# strength NOUN NN dobj
#
#
#      SPACE _SP dep
# “ PUNCT `` punct
# To PART TO aux
# break VERB VB xcomp
# this DET DT det
# sorry ADJ JJ amod
# scheme NOUN NN dobj
# of ADP IN prep
# things NOUN NNS pobj
# entire ADJ JJ amod
# , PUNCT , punct
#
#       SPACE _SP dep
# And CCONJ CC cc
# mould AUX MD aux
# it PRON PRP nsubj
# nearer VERB VB conj
# to ADP IN prep
# the DET DT det
# heart NOUN NN poss
# ’s PART POS case
# desire NOUN NN pobj
# . PUNCT . punct
# ” PUNCT '' punct
#
#
#  SPACE _SP dep
# And CCONJ CC cc
# his PRON PRP$ poss
# victorious ADJ JJ amod
# progress NOUN NN nsubj
# is AUX VBZ aux
# only ADV RB advmod
# beginning VERB VBG ROOT
# to PART TO aux
# take VERB VB xcomp
# effect NOUN NN dobj
# . PUNCT . punct
# How SCONJ WRB advmod
# it PRON PRP nsubj
#
#  SPACE _SP dep
# has AUX VBZ aux
# come VERB VBN advcl
# about ADV RB prep
# , PUNCT , punct
# and CCONJ CC cc
# what PRON WP nsubj
# will AUX MD aux
# be AUX VB conj
# the DET DT det
# eventual ADJ JJ amod
# result NOUN NN attr
# of ADP IN prep
# his PRON PRP$ poss
# domination NOUN NN pobj
#
#  SPACE _SP dep
# of ADP IN prep
# our PRON PRP$ poss
# planet NOUN NN pobj
# , PUNCT , punct
# it PRON PRP nsubj
# is AUX VBZ ROOT
# the DET DT det
# purpose NOUN NN attr
# of ADP IN prep
# what PRON WP nsubj
# follows VERB VBZ pcomp
# to PART TO aux
# elucidate VERB VB xcomp
# . PUNCT . punct
#
#
#
#
#
#                                 SPACE _SP dep
# HEPHÆSTUS PROPN NNP npadvmod
#
#
#
#
#
#                                     SPACE _SP dep
# I PRON PRP compound
#
#
#      SPACE _SP dep
# Ethnologists NOUN NNS nsubj
# believe VERB VBP ROOT
# that SCONJ IN mark
# the DET DT det
# metamorphosis NOUN NN nsubjpass
# from ADP IN prep
# beast NOUN NN npadvmod
# - PUNCT HYPH punct
# like ADJ JJ amod
#
#      SPACE _SP dep
# savage NOUN NN pobj
# to ADP IN prep
# cultured ADJ JJ amod
# civilian NOUN NN pobj
# may AUX MD aux
# be AUX VB auxpass
# proximately ADV RB advmod
# explained VERB VBN ccomp
# as ADP IN prep
# the DET DT det
#
#      SPACE _SP dep
# result NOUN NN pobj
# of ADP IN prep
# accumulated VERB VBN amod
# changes NOUN NNS pobj
# that PRON WDT nsubj
# found VERB VBD relcl
# their PRON PRP$ poss
# initial ADJ JJ amod
# impulses NOUN NNS dobj
#
#      SPACE _SP dep
# in ADP IN prep
# a DET DT det
# half ADJ JJ predet
# - PUNCT HYPH punct
# a DET DT det
# - PUNCT HYPH punct
# dozen NOUN NN pobj
# or CCONJ CC cc
# so ADV RB nummod
# of ADP IN prep
# practical ADJ JJ amod
# inventions NOUN NNS pobj
# . PUNCT . punct
#
#
#
#  SPACE _SP dep
# An DET DT det
# Irish ADJ JJ amod
# poet NOUN NN nsubj
# , PUNCT , punct
# disconsolately ADV RB advmod
# walking VERB VBG advcl
# along ADP IN prep
# Fleet PROPN NNP compound
# Street PROPN NNP pobj
# one NUM CD nummod
# day NOUN NN npadvmod
# , PUNCT , punct
#
#  SPACE _SP dep
# bethought VERB VB ROOT
# himself PRON PRP dobj
# of ADP IN prep
# a DET DT det
# small ADJ JJ amod
# island NOUN NN pobj
# in ADP IN prep
# an DET DT det
# Irish PROPN NNP amod
# lake NOUN NN pobj
# , PUNCT , punct
# where SCONJ WRB advmod
# he PRON PRP nsubj
# could AUX MD aux
#
#  SPACE _SP dep
# escape VERB VB relcl
# from ADP IN prep
# the DET DT det
# noise NOUN NN pobj
# and CCONJ CC cc
# bustle NOUN NN conj
# of ADP IN prep
# the DET DT det
# London PROPN NNP compound
# streets NOUN NNS pobj
# . PUNCT . punct
# He PRON PRP nsubj
# wrote VERB VBD ROOT
# a DET DT det
#
#  SPACE _SP dep
# lovely ADJ JJ amod
# poem NOUN NN dobj
# embodying VERB VBG acl
# that DET DT det
# thought NOUN NN dobj
# , PUNCT , punct
# a DET DT det
# poem NOUN NN appos
# expressing VERB VBG acl
# the DET DT det
# longing NOUN NN dobj
# of ADP IN prep
#
#  SPACE _SP dep
# every DET DT det
# sensitive ADJ JJ amod
# soul NOUN NN pobj
# to PART TO aux
# retire VERB VB advcl
# within ADP IN prep
# itself PRON PRP pobj
# for ADP IN prep
# a DET DT det
# time NOUN NN pobj
# and CCONJ CC cc
# reconstruct VERB VB conj
#
#  SPACE _SP dep
# its PRON PRP$ poss
# world NOUN NN dobj
# from ADP IN prep
# within ADP IN prep
# instead ADV RB advmod
# of ADP IN prep
# having VERB VBG pcomp
# it PRON PRP nsubj
# impressed VERB VBN ccomp
# from ADP IN prep
# without ADP IN pcomp
# . PUNCT . punct
#
#
#  SPACE _SP dep
# Needless ADJ JJ advcl
# to PART TO aux
# say VERB VB xcomp
# , PUNCT , punct
# he PRON PRP nsubj
# did AUX VBD aux
# not PART RB neg
# content VERB VB ROOT
# himself PRON PRP dobj
# with ADP IN prep
# planting VERB VBG pcomp
# nine NUM CD nummod
#
#  SPACE _SP dep
# beans NOUN NNS dobj
# in ADP IN prep
# a DET DT det
# row NOUN NN pobj
# , PUNCT , punct
# as SCONJ IN mark
# he PRON PRP nsubj
# had AUX VBD aux
# longed VERB VBN advcl
# to PART TO aux
# do VERB VB xcomp
# in ADP IN prep
# his PRON PRP$ poss
# fit NOUN NN pobj
# of ADP IN prep
# depression NOUN NN pobj
# . PUNCT . punct
# On ADP IN ROOT
#
#  SPACE _SP dep
# the DET DT det
# contrary NOUN NN pobj
# . PUNCT . punct
# He PRON PRP nsubj
# became VERB VBD ROOT
# an DET DT det
# Irish ADJ JJ amod
# statesman NOUN NN attr
# and CCONJ CC cc
# Senator PROPN NNP conj
# . PUNCT . punct
# He PRON PRP nsubj
# dwelt ADV RB ROOT
#
#  SPACE _SP dep
# in ADP IN prep
# surroundings NOUN NNS pobj
# far ADV RB advmod
# removed VERB VBN acl
# from ADP IN prep
# the DET DT det
# Stone PROPN NNP compound
# Age PROPN NNP pobj
# . PUNCT . punct
# The DET DT det
# very ADJ JJ amod
# chair NOUN NN nsubj
# on ADP IN prep
#
#  SPACE _SP dep
# which PRON WDT pobj
# he PRON PRP nsubj
# sat VERB VBD pcomp
# down ADP RP prt
# to PART TO aux
# write VERB VB advcl
# owed VERB VBD ROOT
# its PRON PRP$ poss
# existence NOUN NN dobj
# to ADP IN dative
# many ADJ JJ amod
# factories NOUN NNS pobj
# and CCONJ CC cc
#
#  SPACE _SP dep
# mechanical ADJ JJ amod
# processes NOUN NNS conj
# . PUNCT . punct
# Its PRON PRP$ poss
# wood NOUN NN nsubjpass
# was AUX VBD auxpass
# derived VERB VBN ROOT
# from ADP IN prep
# planks NOUN NNS pobj
# cut VERB VBN acl
# in ADP IN prep
# the DET DT det
#
#  SPACE _SP dep
# saw ADJ JJ amod
# mills NOUN NNS pobj
# . PUNCT . punct
# Its PRON PRP$ poss
# French ADJ JJ amod
# polish NOUN NN nsubjpass
# , PUNCT , punct
# although SCONJ IN mark
# put VERB VBN advcl
# on ADP RP prt
# by ADP IN prep
# hand NOUN NN pobj
# , PUNCT , punct
# was AUX VBD auxpass
# made VERB VBN ROOT
# of ADP IN prep
#
#  SPACE _SP dep
# constituents――shellac PROPN NNP amod
# , PUNCT , punct
# methylated ADJ JJ amod
# spirit NOUN NN pobj
# , PUNCT , punct
# whitening VERB VBG advcl
# and CCONJ CC cc
# what PRON WP nsubj
# not――drawn NOUN NN conj
#
#  SPACE _SP dep
# from ADP IN prep
# many ADJ JJ amod
# sources NOUN NNS pobj
# , PUNCT , punct
# each PRON DT nsubj
# involving VERB VBG advcl
# a DET DT det
# number NOUN NN dobj
# of ADP IN prep
# ingenious ADJ JJ amod
# inventions NOUN NNS pobj
# . PUNCT . punct
#
#  SPACE _SP dep
# The DET DT det
# coal NOUN NN nsubj
# which PRON WDT nsubj
# made VERB VBD relcl
# his PRON PRP$ poss
# fire NOUN NN nsubjpass
# had AUX VBD aux
# been AUX VBN auxpass
# brought VERB VBN ccomp
# across ADP IN prep
# the DET DT det
# sea NOUN NN pobj
# by ADP IN agent
# a DET DT det
#
#  SPACE _SP dep
# steamer――a PROPN NNP compound
# miracle NOUN NN pobj
# of ADP IN prep
# complicated ADJ JJ pobj
# mechanism――and PUNCT , punct
# the DET DT det
# shovel NOUN NN nsubjpass
# with ADP IN prep
# which PRON WDT pobj
#
#  SPACE _SP dep
# he PRON PRP nsubj
# put VERB VBD relcl
# it PRON PRP dobj
# on ADP RP prt
# had AUX VBD aux
# been AUX VBN auxpass
# mined VERB VBN relcl
# in ADP IN prep
# Belgium PROPN NNP pobj
# , PUNCT , punct
# smelted VERB VBN advcl
# in ADP IN prep
# Germany PROPN NNP pobj
# , PUNCT , punct
# rolled VERB VBD ROOT
# in ADP IN prep
#
#  SPACE _SP dep
# Sheffield PROPN NNP pobj
# , PUNCT , punct
# and CCONJ CC cc
# shaped VERB VBN conj
# and CCONJ CC cc
# finished VERB VBN conj
# in ADP IN prep
# Birmingham PROPN NNP pobj
# . PUNCT . punct
#
#
#  SPACE _SP dep
# Not PART RB neg
# that SCONJ IN mark
# “ PUNCT `` punct
# Inishfree PROPN NNP nsubj
# ” PUNCT '' punct
# was AUX VBD ROOT
# but CCONJ CC cc
# an DET DT det
# idle ADJ JJ amod
# dream NOUN NN attr
# . PUNCT . punct
# There PRON EX expl
# are VERB VBP ROOT
# many ADJ JJ amod
# such ADJ JJ amod
#
#  SPACE _SP dep
# islands NOUN NNS attr
# in ADP IN prep
# Ireland PROPN NNP pobj
# , PUNCT , punct
# peopled VERB VBN acl
# by ADP IN agent
# men NOUN NNS pobj
# and CCONJ CC cc
# women NOUN NNS conj
# and CCONJ CC cc
# children NOUN NNS conj
# , PUNCT , punct
# living VERB VBG conj
# in ADP IN prep
#
#  SPACE _SP dep
# one NUM CD nummod
# - PUNCT HYPH punct
# roomed VERB VBN amod
# mud NOUN NN compound
# hovels NOUN NNS pobj
# on ADP IN prep
# potatoes NOUN NNS pobj
# and CCONJ CC cc
# stewed VERB VBN amod
# tea NOUN NN conj
# , PUNCT , punct
# infested VERB VBN acl
# with ADP IN prep
# vermin NOUN NN pobj
#
#  SPACE _SP dep
# and CCONJ CC cc
# ravaged VERB VBN conj
# by ADP IN agent
# tuberculosis NOUN NN pobj
# and CCONJ CC cc
# other ADJ JJ amod
# infectious ADJ JJ amod
# diseases NOUN NNS conj
# , PUNCT , punct
# people NOUN NNS appos
# who PRON WP nsubj
# , PUNCT , punct
#
#  SPACE _SP dep
# if SCONJ IN mark
# they PRON PRP nsubj
# can AUX MD aux
# not PART RB neg
# emigrate VERB VB advcl
# , PUNCT , punct
# suffer VERB VBP relcl
# their PRON PRP$ poss
# fate NOUN NN dobj
# with ADP IN prep
# a DET DT det
# stolid ADJ JJ amod
# and CCONJ CC cc
# pathetic ADJ JJ conj
#
#  SPACE _SP dep
# resignation NOUN NN pobj
# relieved VERB VBN acl
# by ADP IN agent
# the DET DT det
# hope NOUN NN pobj
# of ADP IN prep
# heavenly PROPN NNP compound
# compensation PROPN NNP compound
# hereafter NOUN NN pobj
# . PUNCT . punct
#
#
#  SPACE _SP dep
# Such ADJ JJ nsubj
# is AUX VBZ ROOT
# Inishfree PROPN NNP attr
# , PUNCT , punct
# stripped VERB VBN acl
# of ADP IN prep
# its PRON PRP$ poss
# glamour NOUN NN pobj
# and CCONJ CC cc
# shown VERB VBN conj
# in ADP IN prep
# its PRON PRP$ poss
# naked ADJ JJ amod
#
#  SPACE _SP dep
# reality NOUN NN pobj
# . PUNCT . punct
#
#
#  SPACE _SP dep
# Savagery PROPN NNP nsubj
# does AUX VBZ aux
# not PART RB neg
# mean VERB VB ROOT
# simplicity NOUN NN dobj
# but CCONJ CC cc
# complexity NOUN NN conj
# , PUNCT , punct
# not PART RB neg
# peace NOUN NN nmod
# but CCONJ CC cc
#
#  SPACE _SP dep
# constant ADJ JJ amod
# dread NOUN NN conj
# , PUNCT , punct
# not PART RB neg
# health NOUN NN npadvmod
# but CCONJ CC cc
# hopeless ADJ JJ amod
# disease NOUN NN conj
# and CCONJ CC cc
# premature ADJ JJ amod
# death NOUN NN conj
# . PUNCT . punct
#
#  SPACE _SP dep
# The DET DT det
# South ADJ JJ amod
# American ADJ JJ amod
# Indian PROPN NNP nsubj
# suffers VERB VBZ ccomp
# acutely ADV RB advmod
# from ADP IN prep
# constipation NOUN NN pobj
# , PUNCT , punct
# which PRON WDT nsubj
# is AUX VBZ relcl
#
#  SPACE _SP dep
# about ADP IN prep
# the DET DT det
# last ADJ JJ amod
# disease NOUN NN pobj
# we PRON PRP nsubj
# should AUX MD aux
# expect VERB VB ROOT
# him PRON PRP nsubj
# to PART TO aux
# suffer VERB VB ccomp
# from ADP IN prep
# . PUNCT . punct
# The DET DT det
# negro NOUN NN nsubjpass
#
#  SPACE _SP dep
# in ADP IN prep
# his PRON PRP$ poss
# native ADJ JJ amod
# Africa PROPN NNP pobj
# is AUX VBZ auxpass
# often ADV RB advmod
# horribly ADV RB advmod
# deformed VERB VBN ROOT
# through ADP IN prep
# neglect NOUN NN pobj
# at ADP IN prep
#
#  SPACE _SP dep
# birth NOUN NN pobj
# , PUNCT , punct
# neglected VERB VBN amod
# injuries NOUN NNS dobj
# , PUNCT , punct
# or CCONJ CC cc
# the DET DT det
# ravages NOUN NNS conj
# of ADP IN prep
# insect NOUN NN compound
# pests NOUN NNS pobj
# . PUNCT . punct
#
#
#  SPACE _SP dep
# It PRON PRP nsubj
# has AUX VBZ aux
# taken VERB VBN ROOT
# mankind NOUN NN dobj
# ten NUM CD compound
# thousand NUM CD nummod
# years NOUN NNS npadvmod
# to PART TO aux
# emerge VERB VB xcomp
# from ADP IN prep
# savagery NOUN NN pobj
# into ADP IN prep
#
#  SPACE _SP dep
# barbarism NOUN NN pobj
# , PUNCT , punct
# and CCONJ CC cc
# from ADP IN prep
# barbarism NOUN NN pobj
# into ADP IN prep
# civilization NOUN NN pobj
# . PUNCT . punct
# Nor CCONJ CC cc
# is AUX VBZ ROOT
# the DET DT det
# process NOUN NN nsubj
#
#  SPACE _SP dep
# yet ADV RB advmod
# completed VERB VBN acl
# . PUNCT . punct
# The DET DT det
# mass NOUN NN nsubj
# of ADP IN prep
# mankind NOUN NN pobj
# is AUX VBZ ROOT
# still ADV RB advmod
# grossly ADV RB advmod
# ignorant ADJ JJ acomp
# . PUNCT . punct
# But CCONJ CC cc
# the DET DT det
#
#  SPACE _SP dep
# leaven NOUN NN nsubj
# of ADP IN prep
# knowledge NOUN NN pobj
# is AUX VBZ aux
# steadily ADV RB advmod
# working VERB VBG ROOT
# and CCONJ CC cc
# pervading VERB VBG conj
# the DET DT det
# mass NOUN NN dobj
# , PUNCT , punct
# and CCONJ CC cc
# the DET DT det
#
#  SPACE _SP dep
# rate NOUN NN nsubj
# of ADP IN prep
# progress NOUN NN pobj
# is AUX VBZ aux
# constantly ADV RB advmod
# rising VERB VBG conj
# . PUNCT . punct
#
#
#  SPACE _SP dep
# Let VERB VB ROOT
# us PRON PRP nsubj
# trace VERB VB ccomp
# this DET DT det
# wonderful ADJ JJ amod
# process NOUN NN dobj
# of ADP IN prep
# civilization NOUN NN pobj
# to ADP IN prep
# its PRON PRP$ poss
# origins NOUN NNS pobj
# and CCONJ CC cc
#
#  SPACE _SP dep
# probe VERB VB conj
# its PRON PRP$ poss
# essential ADJ JJ amod
# nature NOUN NN dobj
# . PUNCT . punct
#
#
#  SPACE _SP dep
# Starting VERB VBG advcl
# somewhere ADV RB advmod
# in ADP IN prep
# the DET DT det
# tropics NOUN NNS pobj
# as ADP IN prep
# a DET DT det
# diminutive ADJ JJ amod
# “ PUNCT `` punct
# sport NOUN NN pobj
# ” PUNCT '' punct
# allied VERB VBN acl
# to ADP IN prep
#
#  SPACE _SP dep
# the DET DT det
# arboreal NOUN NN compound
# ape NOUN NN pobj
# , PUNCT , punct
# man NOUN NN nsubj
# learned VERB VBD ROOT
# to PART TO aux
# use VERB VB xcomp
# tools NOUN NNS dobj
# and CCONJ CC cc
# weapons NOUN NNS conj
# . PUNCT . punct
# This PRON DT nsubj
# was AUX VBD ROOT
# the DET DT det
#
#  SPACE _SP dep
# first ADJ JJ amod
# step NOUN NN attr
# taken VERB VBN acl
# towards ADP IN prep
# the DET DT det
# conquest NOUN NN pobj
# of ADP IN prep
# the DET DT det
# animal NOUN NN compound
# world NOUN NN pobj
# , PUNCT , punct
# his PRON PRP$ poss
# natural ADJ JJ amod
#
#  SPACE _SP dep
# enemies NOUN NNS appos
# . PUNCT . punct
#
#
#  SPACE _SP dep
# We PRON PRP nsubj
# do AUX VBP aux
# not PART RB neg
# know VERB VB ROOT
# how SCONJ WRB advmod
# many ADJ JJ amod
# ages NOUN NNS nsubj
# elapsed VERB VBN ccomp
# before SCONJ IN mark
# the DET DT det
# rough ADJ JJ amod
# stone NOUN NN compound
# hammer NOUN NN nsubj
#
#  SPACE _SP dep
# evolved VERB VBD advcl
# into ADP IN prep
# the DET DT det
# axe NOUN NN pobj
# of ADP IN prep
# polished ADJ JJ amod
# flint NOUN NN pobj
# . PUNCT . punct
# In ADP IN prep
# any DET DT det
# case NOUN NN pobj
# , PUNCT , punct
# the DET DT det
# rough ADJ JJ amod
# stone NOUN NN nsubj
# , PUNCT , punct
#
#  SPACE _SP dep
# even ADV RB advmod
# if SCONJ IN mark
# only ADV RB advmod
# used VERB VBN acl
# for ADP IN prep
# throwing VERB VBG pcomp
# at ADP IN prep
# his PRON PRP$ poss
# enemy NOUN NN pobj
# or CCONJ CC cc
# killing VERB VBG conj
# his PRON PRP$ poss
# prey NOUN NN dobj
# , PUNCT , punct
# was AUX VBD ROOT
# an DET DT det
#
#  SPACE _SP dep
# essentially ADV RB advmod
# new ADJ JJ amod
# departure NOUN NN attr
# in ADP IN prep
# evolution NOUN NN pobj
# , PUNCT , punct
# and CCONJ CC cc
# sounded VERB VBD conj
# the DET DT det
# keynote NOUN NN dobj
# to ADP IN prep
# all PRON DT pobj
#
#  SPACE _SP dep
# that PRON WDT nsubj
# followed VERB VBD relcl
# down ADP RP prt
# to ADP IN prep
# our PRON PRP$ poss
# own ADJ JJ amod
# times NOUN NNS pobj
# . PUNCT . punct
#
#
#  SPACE _SP dep
# Tools NOUN NNS nsubjpass
# and CCONJ CC cc
# weapons NOUN NNS conj
# had AUX VBD aux
# been AUX VBN auxpass
# evolved VERB VBN ROOT
# by ADP IN agent
# other ADJ JJ amod
# animals NOUN NNS pobj
# , PUNCT , punct
# but CCONJ CC cc
# they PRON PRP nsubjpass
# were AUX VBD auxpass
#
#  SPACE _SP dep
# always ADV RB advmod
# organically ADV RB advmod
# connected VERB VBN conj
# with ADP IN prep
# their PRON PRP$ poss
# bodies NOUN NNS pobj
# . PUNCT . punct
# The DET DT det
# tiger NOUN NN poss
# ’s PART POS case
# claws NOUN NNS ROOT
# and CCONJ CC cc
#
#  SPACE _SP dep
# teeth NOUN NNS conj
# , PUNCT , punct
# the DET DT det
# tusks NOUN NNS appos
# of ADP IN prep
# the DET DT det
# elephant NOUN NN pobj
# and CCONJ CC cc
# the DET DT det
# wild ADJ JJ amod
# boar NOUN NN conj
# , PUNCT , punct
# the DET DT det
# beak NOUN NN nsubj
# of ADP IN prep
# the DET DT det
#
#  SPACE _SP dep
# eagle NOUN NN pobj
# were AUX VBD ROOT
# all PRON DT dep
# formidable ADJ JJ amod
# weapons NOUN NNS attr
# and CCONJ CC cc
# useful ADJ JJ amod
# tools NOUN NNS conj
# , PUNCT , punct
# but CCONJ CC cc
# they PRON PRP nsubjpass
# could AUX MD aux
#
#  SPACE _SP dep
# neither CCONJ CC neg
# be AUX VB auxpass
# detached VERB VBN conj
# , PUNCT , punct
# nor CCONJ CC cc
# replaced VERB VBN conj
# , PUNCT , punct
# nor CCONJ CC cc
# exchanged VERB VBD conj
# for ADP IN prep
# other ADJ JJ amod
# tools NOUN NNS pobj
# more ADV RBR advmod
#
#  SPACE _SP dep
# suitable ADJ JJ amod
# to ADP IN prep
# the DET DT det
# occasion NOUN NN pobj
# . PUNCT . punct
# Those DET DT det
# “ PUNCT `` punct
# natural ADJ JJ amod
# ” PUNCT '' punct
# tools NOUN NNS nsubjpass
# and CCONJ CC cc
# weapons NOUN NNS conj
# had AUX VBD aux
# all PRON DT nsubjpass
#
#  SPACE _SP dep
# been AUX VBN auxpass
# produced VERB VBN ROOT
# by ADP IN agent
# “ PUNCT `` punct
# evolution NOUN NN pobj
# , PUNCT , punct
# ” PUNCT '' punct
# in ADP IN prep
# other ADJ JJ amod
# words NOUN NNS pobj
# , PUNCT , punct
# by ADP IN agent
# a DET DT det
# mysterious ADJ JJ amod
# agency NOUN NN pobj
#
#  SPACE _SP dep
# which PRON WDT dobj
# some PRON DT nsubj
# call VERB VBP relcl
# God PROPN NNP dobj
# , PUNCT , punct
# some DET DT det
# ...
# . X LS punct
# Information NOUN NN nsubj
# about ADP IN prep
# the DET DT det
# Mission PROPN NNP pobj
# of ADP IN prep
# Project PROPN NNP compound
# Gutenberg PROPN NNP pobj
# ™ PUNCT HYPH punct
#
#
#  SPACE _SP dep
# Project PROPN NNP compound
# Gutenberg PROPN NNP appos
# ™ X ADD appos
# is AUX VBZ ROOT
# synonymous ADJ JJ acomp
# with ADP IN prep
# the DET DT det
# free ADJ JJ amod
# distribution NOUN NN pobj
# of ADP IN prep
#
#  SPACE _SP dep
# electronic ADJ JJ amod
# works NOUN NNS pobj
# in ADP IN prep
# formats NOUN NNS pobj
# readable ADJ JJ amod
# by ADP IN prep
# the DET DT det
# widest ADJ JJS amod
# variety NOUN NN pobj
# of ADP IN prep
#
#  SPACE _SP dep
# computers NOUN NNS pobj
# including VERB VBG prep
# obsolete ADJ JJ amod
# , PUNCT , punct
# old ADJ JJ amod
# , PUNCT , punct
# middle ADJ JJ amod
# - PUNCT HYPH punct
# aged ADJ JJ amod
# and CCONJ CC cc
# new ADJ JJ conj
# computers NOUN NNS pobj
# . PUNCT . punct
# It PRON PRP nsubj
#
#  SPACE _SP dep
# exists VERB VBZ ROOT
# because SCONJ IN prep
# of ADP IN pcomp
# the DET DT det
# efforts NOUN NNS pobj
# of ADP IN prep
# hundreds NOUN NNS pobj
# of ADP IN prep
# volunteers NOUN NNS pobj
# and CCONJ CC cc
# donations NOUN NNS conj
#
#  SPACE _SP dep
# from ADP IN prep
# people NOUN NNS pobj
# in ADP IN prep
# all DET DT det
# walks NOUN NNS pobj
# of ADP IN prep
# life NOUN NN pobj
# . PUNCT . punct
#
#
#  SPACE _SP dep
# Volunteers NOUN NNS nsubj
# and CCONJ CC cc
# financial ADJ JJ amod
# support NOUN NN conj
# to PART TO aux
# provide VERB VB relcl
# volunteers NOUN NNS dobj
# with ADP IN prep
# the DET DT det
#
#  SPACE _SP dep
# assistance NOUN NN pobj
# they PRON PRP nsubj
# need VERB VBP relcl
# are AUX VBP ROOT
# critical ADJ JJ acomp
# to ADP IN prep
# reaching VERB VBG pcomp
# Project PROPN NNP compound
# Gutenberg PROPN NNP dobj
# ™ X ADD dobj
# ’s PART POS case
#
#  SPACE _SP dep
# goals NOUN NNS dobj
# and CCONJ CC cc
# ensuring VERB VBG conj
# that SCONJ IN mark
# the DET DT det
# Project PROPN NNP compound
# Gutenberg PROPN NNP compound
# ™ NOUN NN compound
# collection NOUN NN nsubj
# will AUX MD aux
#
#  SPACE _SP dep
# remain VERB VB ccomp
# freely ADV RB advmod
# available ADJ JJ acomp
# for SCONJ IN mark
# generations NOUN NNS nsubj
# to PART TO aux
# come VERB VB advcl
# . PUNCT . punct
# In ADP IN prep
# 2001 NUM CD pobj
# , PUNCT , punct
# the DET DT det
# Project PROPN NNP compound
#
#  SPACE _SP dep
# Gutenberg PROPN NNP compound
# Literary PROPN NNP compound
# Archive PROPN NNP compound
# Foundation PROPN NNP nsubjpass
# was AUX VBD auxpass
# created VERB VBN ROOT
# to PART TO aux
# provide VERB VB advcl
# a DET DT det
# secure ADJ JJ amod
#
#  SPACE _SP dep
# and CCONJ CC cc
# permanent ADJ JJ amod
# future NOUN NN dobj
# for ADP IN prep
# Project PROPN NNP compound
# Gutenberg PROPN NNP pobj
# ™ PUNCT : dep
# and CCONJ CC cc
# future NOUN NN compound
#
#  SPACE _SP dep
# generations NOUN NNS conj
# . PUNCT . punct
# To PART TO aux
# learn VERB VB advcl
# more ADJ JJR dobj
# about ADP IN prep
# the DET DT det
# Project PROPN NNP compound
# Gutenberg PROPN NNP compound
# Literary PROPN NNP compound
#
#  SPACE _SP dep
# Archive PROPN NNP compound
# Foundation PROPN NNP pobj
# and CCONJ CC cc
# how SCONJ WRB advmod
# your PRON PRP$ poss
# efforts NOUN NNS nsubj
# and CCONJ CC cc
# donations NOUN NNS conj
# can AUX MD aux
# help VERB VB conj
# , PUNCT , punct
# see VERB VB ROOT
#
#  SPACE _SP dep
# Sections NOUN NNS dobj
# 3 NUM CD nummod
# and CCONJ CC cc
# 4 NUM CD conj
# and CCONJ CC cc
# the DET DT det
# Foundation PROPN NNP compound
# information NOUN NN compound
# page NOUN NN conj
# at ADP IN prep
# www.gutenberg.org NUM CD pobj
# . PUNCT . punct
#
#
#  SPACE _SP dep
# Section PROPN NNP nsubj
# 3 NUM CD nummod
# . PUNCT . punct
# Information NOUN NN nsubj
# about ADP IN prep
# the DET DT det
# Project PROPN NNP compound
# Gutenberg PROPN NNP compound
# Literary PROPN NNP compound
# Archive PROPN NNP compound
# Foundation PROPN NNP pobj
#
#
#  SPACE _SP dep
# The DET DT det
# Project PROPN NNP compound
# Gutenberg PROPN NNP compound
# Literary PROPN NNP compound
# Archive PROPN NNP compound
# Foundation PROPN NNP nsubj
# is AUX VBZ ROOT
# a DET DT det
# non ADJ JJ amod
# - ADJ JJ amod
# profit ADJ JJ amod
#
#  SPACE _SP dep
# 501(c)(3 NOUN NNS nmod
# ) PUNCT -RRB- punct
# educational ADJ JJ amod
# corporation NOUN NN attr
# organized VERB VBN acl
# under ADP IN prep
# the DET DT det
# laws NOUN NNS pobj
# of ADP IN prep
# the DET DT det
#
#  SPACE _SP dep
# state NOUN NN pobj
# of ADP IN prep
# Mississippi PROPN NNP pobj
# and CCONJ CC cc
# granted VERB VBD conj
# tax NOUN NN nmod
# exempt ADJ JJ amod
# status NOUN NN dobj
# by ADP IN prep
# the DET DT det
# Internal PROPN NNP compound
#
#  SPACE _SP dep
# Revenue PROPN NNP compound
# Service PROPN NNP pobj
# . PUNCT . punct
# The DET DT det
# Foundation PROPN NNP poss
# ’s PART POS case
# EIN PROPN NNP nmod
# or CCONJ CC cc
# federal ADJ JJ amod
# tax NOUN NN compound
# identification NOUN NN conj
#
#  SPACE _SP dep
# number NOUN NN nsubj
# is AUX VBZ ROOT
# 64 NUM CD attr
# - SYM SYM punct
# 6221541 NUM CD prep
# . PUNCT . punct
# Contributions NOUN NNS nsubj
# to ADP IN prep
# the DET DT det
# Project PROPN NNP compound
# Gutenberg PROPN NNP compound
# Literary PROPN NNP compound
#
#  SPACE _SP dep
# Archive PROPN NNP compound
# Foundation PROPN NNP pobj
# are AUX VBP ROOT
# tax NOUN NN npadvmod
# deductible ADJ JJ acomp
# to ADP IN prep
# the DET DT det
# full ADJ JJ amod
# extent NOUN NN pobj
# permitted VERB VBN acl
# by ADP IN agent
#
#  SPACE _SP dep
# U.S. PROPN NNP nmod
# federal ADJ JJ amod
# laws NOUN NNS pobj
# and CCONJ CC cc
# your PRON PRP$ poss
# state NOUN NN poss
# ’s PART POS case
# laws NOUN NNS conj
# . PUNCT . punct
#
#
#  SPACE _SP dep
# The DET DT det
# Foundation PROPN NNP poss
# ’s PART POS case
# business NOUN NN compound
# office NOUN NN nsubjpass
# is AUX VBZ auxpass
# located VERB VBN ROOT
# at ADP IN prep
# 809 NUM CD nummod
# North PROPN NNP nmod
# 1500 NUM CD nummod
# West PROPN NNP pobj
# , PUNCT , punct
#
#  SPACE _SP dep
# Salt PROPN NNP compound
# Lake PROPN NNP compound
# City PROPN NNP appos
# , PUNCT , punct
# UT PROPN NNP appos
# 84116 NUM CD nummod
# , PUNCT , punct
# ( PUNCT -LRB- punct
# 801 NUM CD appos
# ) PUNCT -RRB- punct
# 596 NUM CD nummod
# - SYM SYM punct
# 1887 NUM CD prep
# . PUNCT . punct
# Email NOUN NN compound
# contact NOUN NN compound
# links NOUN NNS nsubjpass
# and CCONJ CC cc
# up ADV RB conj
#
#  SPACE _SP dep
# to ADP IN prep
# date NOUN NN pobj
# contact NOUN NN compound
# information NOUN NN pobj
# can AUX MD aux
# be AUX VB auxpass
# found VERB VBN ROOT
# at ADP IN prep
# the DET DT det
# Foundation PROPN NNP poss
# ’s PART POS case
# website NOUN NN pobj
#
#  SPACE _SP dep
# and CCONJ CC cc
# official ADJ JJ amod
# page NOUN NN conj
# at ADP IN prep
# www.gutenberg.org/contact NOUN NN pobj
#
#
#  SPACE _SP dep
# Section NOUN NN pobj
# 4 NUM CD nummod
# . PUNCT . punct
# Information NOUN NN nsubj
# about ADP IN prep
# Donations NOUN NNS pobj
# to ADP IN prep
# the DET DT det
# Project PROPN NNP compound
# Gutenberg PROPN NNP compound
#
#  SPACE _SP dep
# Literary PROPN NNP compound
# Archive PROPN NNP compound
# Foundation PROPN NNP compound
#
#
#  SPACE _SP dep
# Project PROPN NNP compound
# Gutenberg PROPN NNP pobj
# ™ X ADD conj
# depends VERB VBZ ROOT
# upon SCONJ IN prep
# and CCONJ CC cc
# can AUX MD aux
# not PART RB neg
# survive VERB VB conj
# without ADP IN prep
# widespread ADJ JJ amod
#
#  SPACE _SP dep
# public ADJ JJ amod
# support NOUN NN pobj
# and CCONJ CC cc
# donations NOUN NNS conj
# to PART TO aux
# carry VERB VB advcl
# out ADP RP prt
# its PRON PRP$ poss
# mission NOUN NN dobj
# of ADP IN prep
#
#  SPACE _SP dep
# increasing VERB VBG pcomp
# the DET DT det
# number NOUN NN dobj
# of ADP IN prep
# public ADJ JJ amod
# domain NOUN NN pobj
# and CCONJ CC cc
# licensed VERB VBN amod
# works NOUN NNS conj
# that PRON WDT nsubjpass
# can AUX MD aux
# be AUX VB auxpass
#
#  SPACE _SP dep
# freely ADV RB advmod
# distributed VERB VBN relcl
# in ADP IN prep
# machine NOUN NN npadvmod
# - PUNCT HYPH punct
# readable ADJ JJ amod
# form NOUN NN pobj
# accessible ADJ JJ amod
# by ADP IN prep
# the DET DT det
# widest ADJ JJ amod
#
#  SPACE _SP dep
# array NOUN NN pobj
# of ADP IN prep
# equipment NOUN NN pobj
# including VERB VBG prep
# outdated ADJ JJ amod
# equipment NOUN NN pobj
# . PUNCT . punct
# Many ADJ JJ amod
# small ADJ JJ amod
# donations NOUN NNS nsubj
#
#  SPACE _SP dep
# ( PUNCT -LRB- punct
# $ SYM $ quantmod
# 1 NUM CD quantmod
# to PART TO quantmod
# $ SYM $ quantmod
# 5,000 NUM CD appos
# ) PUNCT -RRB- punct
# are AUX VBP ROOT
# particularly ADV RB advmod
# important ADJ JJ acomp
# to ADP IN prep
# maintaining VERB VBG pcomp
# tax NOUN NN nmod
# exempt ADJ JJ amod
#
#  SPACE _SP dep
# status NOUN NN dobj
# with ADP IN prep
# the DET DT det
# IRS PROPN NNP pobj
# . PUNCT . punct
#
#
#  SPACE _SP dep
# The DET DT det
# Foundation PROPN NNP nsubj
# is AUX VBZ ROOT
# committed VERB VBN acomp
# to ADP IN prep
# complying VERB VBG pcomp
# with ADP IN prep
# the DET DT det
# laws NOUN NNS pobj
# regulating VERB VBG acl
#
#  SPACE _SP dep
# charities NOUN NNS dobj
# and CCONJ CC cc
# charitable ADJ JJ amod
# donations NOUN NNS conj
# in ADP IN prep
# all DET DT det
# 50 NUM CD nummod
# states NOUN NNS pobj
# of ADP IN prep
# the DET DT det
# United PROPN NNP compound
#
#  SPACE _SP dep
# States PROPN NNPS pobj
# . PUNCT . punct
# Compliance NOUN NN compound
# requirements NOUN NNS nsubj
# are AUX VBP ROOT
# not PART RB neg
# uniform ADJ JJ acomp
# and CCONJ CC cc
# it PRON PRP nsubj
# takes VERB VBZ conj
# a DET DT det
#
#  SPACE _SP dep
# considerable ADJ JJ amod
# effort NOUN NN dobj
# , PUNCT , punct
# much ADJ JJ amod
# paperwork NOUN NN conj
# and CCONJ CC cc
# many ADJ JJ amod
# fees NOUN NNS conj
# to PART TO aux
# meet VERB VB xcomp
# and CCONJ CC cc
# keep VERB VB conj
# up ADP RP prt
#
#  SPACE _SP dep
# with ADP IN prep
# these DET DT det
# requirements NOUN NNS pobj
# . PUNCT . punct
# We PRON PRP nsubj
# do AUX VBP aux
# not PART RB neg
# solicit VERB VB ROOT
# donations NOUN NNS dobj
# in ADP IN prep
# locations NOUN NNS pobj
#
#  SPACE _SP dep
# where SCONJ WRB advmod
# we PRON PRP nsubj
# have AUX VBP aux
# not PART RB neg
# received VERB VBN relcl
# written VERB VBN amod
# confirmation NOUN NN dobj
# of ADP IN prep
# compliance NOUN NN pobj
# . PUNCT . punct
# To ADP IN ROOT
# SEND PROPN NNP compound
#
#  SPACE _SP dep
# DONATIONS NOUN NNS pobj
# or CCONJ CC cc
# determine VERB VB conj
# the DET DT det
# status NOUN NN dobj
# of ADP IN prep
# compliance NOUN NN pobj
# for ADP IN prep
# any DET DT det
# particular ADJ JJ amod
# state NOUN NN compound
#
#  SPACE _SP dep
# visit NOUN NN pobj
# www.gutenberg.org/donate NOUN NN npadvmod
# . PUNCT . punct
#
#
#  SPACE _SP dep
# While SCONJ IN mark
# we PRON PRP nsubj
# can AUX MD aux
# not PART RB advcl
# and CCONJ CC cc
# do AUX VB aux
# not PART RB neg
# solicit VERB VB conj
# contributions NOUN NNS dobj
# from ADP IN prep
# states NOUN NNS pobj
# where SCONJ WRB advmod
# we PRON PRP nsubj
#
#  SPACE _SP dep
# have AUX VBP aux
# not PART RB neg
# met VERB VBN relcl
# the DET DT det
# solicitation NOUN NN compound
# requirements NOUN NNS dobj
# , PUNCT , punct
# we PRON PRP nsubj
# know VERB VBP ROOT
# of ADP IN prep
# no DET DT det
# prohibition NOUN NN pobj
#
#  SPACE _SP dep
# against ADP IN prep
# accepting VERB VBG pcomp
# unsolicited ADJ JJ amod
# donations NOUN NNS dobj
# from ADP IN prep
# donors NOUN NNS pobj
# in ADP IN prep
# such ADJ JJ amod
# states NOUN NNS pobj
# who PRON WP nsubj
#
#  SPACE _SP dep
# approach VERB VBP relcl
# us PRON PRP dobj
# with ADP IN prep
# offers NOUN NNS pobj
# to PART TO aux
# donate VERB VB acl
# . PUNCT . punct
#
#
#  SPACE _SP dep
# International ADJ JJ amod
# donations NOUN NNS nsubjpass
# are AUX VBP auxpass
# gratefully ADV RB advmod
# accepted VERB VBN ROOT
# , PUNCT , punct
# but CCONJ CC cc
# we PRON PRP nsubj
# can AUX MD aux
# not PART RB neg
# make VERB VB conj
#
#  SPACE _SP dep
# any DET DT det
# statements NOUN NNS dobj
# concerning VERB VBG acl
# tax NOUN NN compound
# treatment NOUN NN dobj
# of ADP IN prep
# donations NOUN NNS pobj
# received VERB VBN acl
# from ADP IN prep
#
#  SPACE _SP dep
# outside ADP IN prep
# the DET DT det
# United PROPN NNP compound
# States PROPN NNP pobj
# . PUNCT . punct
# U.S. PROPN NNP compound
# laws NOUN NNS nsubj
# alone ADV RB amod
# swamp VERB VBP ROOT
# our PRON PRP$ poss
# small ADJ JJ amod
# staff NOUN NN dobj
# . PUNCT . punct
#
#
#  SPACE _SP dep
# Please INTJ UH intj
# check VERB VB ROOT
# the DET DT det
# Project PROPN NNP compound
# Gutenberg PROPN NNP compound
# web NOUN NN compound
# pages NOUN NNS dobj
# for ADP IN prep
# current ADJ JJ amod
# donation NOUN NN compound
#
#  SPACE _SP dep
# methods NOUN NNS pobj
# and CCONJ CC cc
# addresses NOUN NNS conj
# . PUNCT . punct
# Donations NOUN NNS nsubjpass
# are AUX VBP auxpass
# accepted VERB VBN ROOT
# in ADP IN prep
# a DET DT det
# number NOUN NN pobj
# of ADP IN prep
# other ADJ JJ amod
#
#  SPACE _SP dep
# ways NOUN NNS pobj
# including VERB VBG prep
# checks NOUN NNS pobj
# , PUNCT , punct
# online ADJ JJ amod
# payments NOUN NNS conj
# and CCONJ CC cc
# credit NOUN NN compound
# card NOUN NN compound
# donations NOUN NNS conj
# . PUNCT . punct
# To PART TO aux
#
#  SPACE _SP dep
# donate VERB VB advcl
# , PUNCT , punct
# please INTJ UH intj
# visit VERB VB ROOT
# : PUNCT : punct
# www.gutenberg.org/donate NUM CD npadvmod
# . PUNCT . punct
#
#
#  SPACE _SP dep
# Section NOUN NN ROOT
# 5 NUM CD nummod
# . PUNCT . punct
# General PROPN NNP compound
# Information PROPN NNP nsubj
# About PROPN NNP prep
# Project PROPN NNP compound
# Gutenberg PROPN NNP pobj
# ™ X ADD npadvmod
# electronic ADJ JJ amod
# works NOUN NNS compound
#
#
#  SPACE _SP dep
# Professor PROPN NNP compound
# Michael PROPN NNP compound
# S. PROPN NNP compound
# Hart PROPN NNP nsubj
# was AUX VBD ROOT
# the DET DT det
# originator NOUN NN attr
# of ADP IN prep
# the DET DT det
# Project PROPN NNP compound
#
#  SPACE _SP dep
# Gutenberg PROPN NNP pobj
# ™ NOUN NN compound
# concept NOUN NN attr
# of ADP IN prep
# a DET DT det
# library NOUN NN pobj
# of ADP IN prep
# electronic ADJ JJ amod
# works NOUN NNS pobj
# that PRON WDT nsubjpass
# could AUX MD aux
# be AUX VB auxpass
#
#  SPACE _SP dep
# freely ADV RB advmod
# shared VERB VBN relcl
# with ADP IN prep
# anyone PRON NN pobj
# . PUNCT . punct
# For ADP IN prep
# forty NUM CD nummod
# years NOUN NNS pobj
# , PUNCT , punct
# he PRON PRP nsubj
# produced VERB VBD ROOT
# and CCONJ CC cc
#
#  SPACE _SP dep
# distributed VERB VBD conj
# Project PROPN NNP compound
# Gutenberg PROPN NNP dobj
# ™ PUNCT : compound
# eBooks PROPN NNP appos
# with ADP IN prep
# only ADV RB advmod
# a DET DT det
# loose ADJ JJ amod
# network NOUN NN pobj
# of ADP IN prep
#
#  SPACE _SP dep
# volunteer NOUN NN compound
# support NOUN NN pobj
# . PUNCT . punct
#
#
#  SPACE _SP dep
# Project PROPN NNP compound
# Gutenberg PROPN NNP nsubjpass
# ™ PROPN NNP compound
# eBooks PROPN NNP nsubjpass
# are AUX VBP auxpass
# often ADV RB advmod
# created VERB VBN ROOT
# from ADP IN prep
# several ADJ JJ amod
# printed VERB VBN amod
#
#  SPACE _SP dep
# editions NOUN NNS pobj
# , PUNCT , punct
# all PRON DT nsubjpass
# of ADP IN prep
# which PRON WDT pobj
# are AUX VBP auxpass
# confirmed VERB VBN relcl
# as SCONJ IN mark
# not PART RB neg
# protected VERB VBN advcl
# by ADP IN agent
# copyright NOUN NN pobj
# in ADP IN prep
#
#  SPACE _SP dep
# the DET DT det
# U.S. PROPN NNP pobj
# unless SCONJ IN mark
# a DET DT det
# copyright NOUN NN compound
# notice NOUN NN nsubjpass
# is AUX VBZ auxpass
# included VERB VBN advcl
# . PUNCT . punct
# Thus ADV RB advmod
# , PUNCT , punct
# we PRON PRP nsubj
# do AUX VBP aux
# not PART RB neg
#
#  SPACE _SP dep
# necessarily ADV RB advmod
# keep VERB VB ROOT
# eBooks PROPN NNP dobj
# in ADP IN prep
# compliance NOUN NN pobj
# with ADP IN prep
# any DET DT det
# particular ADJ JJ amod
# paper NOUN NN compound
#
#  SPACE _SP dep
# edition NOUN NN pobj
# . PUNCT . punct
#
#
#  SPACE _SP dep
# Most ADJ JJS amod
# people NOUN NNS nsubj
# start VERB VBP ROOT
# at ADP IN prep
# our PRON PRP$ poss
# website NOUN NN pobj
# which PRON WDT nsubj
# has VERB VBZ ccomp
# the DET DT det
# main ADJ JJ amod
# PG PROPN NNP compound
# search NOUN NN compound
#
#  SPACE _SP dep
# facility NOUN NN dobj
# : PUNCT : punct
# www.gutenberg.org NUM CD appos
# . PUNCT . punct
#
#
#  SPACE _SP dep
# This DET DT det
# website NOUN NN nsubj
# includes VERB VBZ ROOT
# information NOUN NN dobj
# about ADP IN prep
# Project PROPN NNP compound
# Gutenberg PROPN NNP pobj
# ™ X ADD appos
# , PUNCT , punct
#
#  SPACE _SP dep
# including VERB VBG prep
# how SCONJ WRB advmod
# to PART TO aux
# make VERB VB pcomp
# donations NOUN NNS dobj
# to ADP IN prep
# the DET DT det
# Project PROPN NNP compound
# Gutenberg PROPN NNP compound
# Literary PROPN NNP compound
#
#  SPACE _SP dep
# Archive PROPN NNP compound
# Foundation PROPN NNP pobj
# , PUNCT , punct
# how SCONJ WRB advmod
# to PART TO aux
# help VERB VB ccomp
# produce VERB VB xcomp
# our PRON PRP$ poss
# new ADJ JJ amod
# eBooks PROPN NNP dobj
# , PUNCT , punct
# and CCONJ CC cc
# how SCONJ WRB advmod
# to PART TO aux
#
#  SPACE _SP dep
# subscribe VERB VB conj
# to ADP IN prep
# our PRON PRP$ poss
# email NOUN NN compound
# newsletter NOUN NN pobj
# to PART TO aux
# hear VERB VB advcl
# about ADP IN prep
# new ADJ JJ amod
# eBooks PROPN NNP pobj
# . PUNCT . punct
#
#
#
#  SPACE _SP dep

# %% [markdown]
#  A few common and rare items or elements of speech:
#
# # Common:
#
# The most prevalent speech unit is the noun (NN), which includes terms like "eBook," "Machine," "use," "parts," "world," "cost," and "restrictions."
# Proper nouns such as "Project Gutenberg," "Hephaestus," "Soul," and "United States" are examples of PROPN (NNP).
# ADP (IN): Adjectives such as "of," "for," "in," "at," and "with."
# Determiners such as "The," "This," "the," "no," and "a" are DET (DT)."
# PUNCT: Characters such as ";", ",", ".", and ":".
#
# # uncommon
#
# Coordination conjunctions (CCONJ, CC) include "or," "and," and "but."
# ADV (RB): Adverbs such as "whatsoever," "almost," and "anywhere."
# PRON (NN): Identifiers such as "it," "anyone," and "you."
# VERB (VB): Words that start with "is," "copy," "give," "use," and "re."

# %% [markdown]
# # Insights:
# These patterns indicate that the content is probably a preamble or introduction stressing the eBook's accessibility and usage rights. Appropriate words and precise wording suggest a formal or educational tone.
# All in all, this section provides legal, metadata, and accessibility information regarding the eBook "Hephaestus; or, The Soul of the Machine," with a focus on its accessibility and permissible use.

# %% [markdown]
# ## Exercise 2
#
# Apply spaCy to extract the most meaningful content from your documents, considering options like excluding stop words or focusing on nouns (i.e. preprocessing and filtering).
#
# Perform a sentiment analysis on the refined data. Create visualization of your result.
#
# Summarize your results by explaining how sentiment changes across sections.

# %%
import requests
import spacy
from spacy import displacy
from collections import Counter
import matplotlib.pyplot as plt

nlp = spacy.load("en_core_web_sm")

url = "https://www.gutenberg.org/cache/epub/73182/pg73182.txt"
response = requests.get(url)
text = response.text

doc = nlp(text)

noun_chunks = [chunk.text.lower() for chunk in doc.noun_chunks if not any(token.is_stop for token in chunk)]

sentences = [sent.text.strip() for sent in doc.sents]
sentiment_scores = [sent.sentiment for sent in doc.sents]

plt.figure(figsize=(12, 6))
plt.plot(range(len(sentiment_scores)), sentiment_scores)
plt.xlabel('Sentence Index')
plt.ylabel('Sentiment Score')
plt.title('The quest of Iranon')
plt.grid(True)
plt.show()

print("Sentiment changes across sections:")
for i, score in enumerate(sentiment_scores[:10]): 
    print(f"Sentence {i + 1}: {score}")
# Out:
# Sentiment changes across sections:
# Sentence 1: 0.0
# Sentence 2: 0.0
# Sentence 3: 0.0
# Sentence 4: 0.0
# Sentence 5: 0.0
# Sentence 6: 0.0
# Sentence 7: 0.0
# Sentence 8: 0.0
# Sentence 9: 0.0
# Sentence 10: 0.0

# %% [markdown]
# Insights:
# The plot visualizes the distribution of sentiment scores across the sentences, allowing you to see the overall sentiment trend of the text. In this case, it seems that the sentiment scores are consistently neutral (around 0) for the first 10 sentences.
# The text of "The Quest of Iranon" seems to begin with a neutral sentiment in the first few sentences, according to the preliminary sentiment analysis. A more thorough understanding of the sentiment running through the text might be possible with additional study beyond the first ten sentences.
